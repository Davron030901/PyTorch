# %% [markdown]
# <a href="https://colab.research.google.com/github/Davron030901/PyTorch/blob/main/PyTorch_Hub_with_YOLOV5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #YOLO5

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# https://pytorch.org/hub/ultralytics_yolov5/

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import torch
from PIL import Image
import torchvision.transforms as T
# Model
model = torch.hub.load('ultralytics/yolov5', 'yolov5s', pretrained=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/hub.py:330: UserWarning: You are about to download and run code from an untrusted repository. In a future release, this won't be allowed. To add the repository to your trusted list, change the command to {calling_fn}(..., trust_repo=False) and a command prompt will appear asking for an explicit confirmation of trust, or load(..., trust_repo=True), which will assume that the prompt is to be answered with 'yes'. You can also use load(..., trust_repo='check') which will only prompt for confirmation if the repo is not already trusted. This will eventually be the default behaviour
#   warnings.warn(
# Downloading: "https://github.com/ultralytics/yolov5/zipball/master" to /root/.cache/torch/hub/master.zip
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# ...

# %%
# !wget -O cars.jpg https://www.uzdaily.uz/storage/img/cars/cars-road.jpg
import torch
from PIL import Image
model = torch.hub.load('ultralytics/yolov5', 'yolov5s', pretrained=True)
imgs = ['https://i2-prod.chroniclelive.co.uk/incoming/article28823827.ece/ALTERNATES/s810/0_Cost-of-living-crisis.jpg'] #rasm linki o'chgan bo'lishi mumkin
# Out:
# --2025-02-01 11:13:54--  https://www.uzdaily.uz/storage/img/cars/cars-road.jpg
# Resolving www.uzdaily.uz (www.uzdaily.uz)... 165.232.79.227
# Connecting to www.uzdaily.uz (www.uzdaily.uz)|165.232.79.227|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 26106 (25K) [text/html]
# Saving to: ‘cars.jpg’
#
# cars.jpg            100%[===================>]  25.49K  --.-KB/s    in 0s
#
# 2025-02-01 11:13:56 (227 MB/s) - ‘cars.jpg’ saved [26106/26106]
# Using cache found in /root/.cache/torch/hub/ultralytics_yolov5_master
# YOLOv5 🚀 2025-2-1 Python-3.10.12 torch-2.5.1+cu121 CPU
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# Adding AutoShape...

# %%
results = model(imgs)
# results.print()
# results.show()
print(results.names)
# nomi bo'yicha prediction qiladi
print(results.xyxy)
print(results.xywh)
# Out:
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# ...

# %%
results.show()
# Out:
# <PIL.Image.Image image mode=RGB size=810x539>

# %%
import torch
import cv2
import numpy as np
from PIL import Image
import requests
from io import BytesIO

# Load YOLOv5 model
model = torch.hub.load('ultralytics/yolov5', 'yolov5s', pretrained=True)

# Download and load image
url = "https://raw.githubusercontent.com/Davron030901/OpenCv/refs/heads/main/image/fivecars.webp"
response = requests.get(url)
img = cv2.imdecode(np.frombuffer(response.content, np.uint8), cv2.IMREAD_COLOR)

if img is None:
    raise ValueError("Failed to load image")

# Inference and display
results = model(img)

# Process predictions
predictions = results.pandas().xyxy[0]
for index, row in predictions.iterrows():
    x1, y1 = int(row['xmin']), int(row['ymin'])
    x2, y2 = int(row['xmax']), int(row['ymax'])
    label = f"{row['name']}: {row['confidence']:.2f}"

    cv2.rectangle(img, (x1, y1), (x2, y2), (0, 255, 0), 2)
    cv2.putText(img, label, (x1, y1-10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0, 255, 0), 2)

# For Colab display
from IPython.display import Image
cv2.imwrite('output.jpg', img)
Image('output.jpg')
# Out:
# Using cache found in /root/.cache/torch/hub/ultralytics_yolov5_master
# YOLOv5 🚀 2025-2-1 Python-3.10.12 torch-2.5.1+cu121 CPU
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# Adding AutoShape...
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):

# %%
import torch
import requests
import numpy as np
import matplotlib.pyplot as plt
import cv2

# Load model
model = torch.hub.load('ultralytics/yolov5', 'yolov5s', pretrained=True)

# Download and load reliable test image
url = "https://raw.githubusercontent.com/Davron030901/OpenCv/refs/heads/main/image/fivecars.webp"
response = requests.get(url)
img = cv2.imdecode(np.frombuffer(response.content, np.uint8), cv2.IMREAD_COLOR)

# Run inference
results = model(img)

# Draw predictions
predictions = results.pandas().xyxy[0]
for index, row in predictions.iterrows():
   x1, y1 = int(row['xmin']), int(row['ymin'])
   x2, y2 = int(row['xmax']), int(row['ymax'])
   label = f"{row['name']}: {row['confidence']:.2f}"

   cv2.rectangle(img, (x1, y1), (x2, y2), (0, 255, 0), 2)
   cv2.putText(img, label, (x1, y1-10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0, 255, 0), 2)

# Display with matplotlib
plt.figure(figsize=(12, 8))
plt.imshow(img)
plt.axis('off')
plt.show()
# Out:
# Using cache found in /root/.cache/torch/hub/ultralytics_yolov5_master
# YOLOv5 🚀 2025-2-1 Python-3.10.12 torch-2.5.1+cu121 CPU
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# Adding AutoShape...
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
