# %% [markdown]
# <a href="https://colab.research.google.com/github/Davron030901/PyTorch/blob/main/7_PyTorch_Fashion_MNSIT_Part_1_No_Regularisation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Regularisation in PyTorch - Part 1**
# ### **First we train a CNN on the Fashion-MNIST Dataset usng NO Regularisation Methods**
#
# ![](https://github.com/rajeevratan84/ModernComputerVision/raw/main/CleanShot%202020-12-02%20at%204.01.54%402x.png)
# ---
#
#
#
# ---
#
#
# In this lesson, we first learn to create a **simple Convolutional Neural Network model** in PyTorch and train it to **classify images in the Fashion-MNIST Dataset**, without the use of any regularisation methods.
# 1. Import PyTorch libraries, define our Transformers, Load our dataset and Visualize our images.
# 2. Build a Simple CNN without Regularisation
# 3. Train Our CNN
# 3. Take a look at Data Augmentation

# %% [markdown]
# # **Import PyTorch libraries, Define Transfomers and Load & Visualise Dataset**

# %%
# Import PyTorch
import torch
import PIL

# We use torchvision to get our dataset and useful image transformations
import torchvision
import torchvision.transforms as transforms

# Import PyTorch's optimization libary and nn
# nn is used as the basic building block for our Network graphs
import torch.optim as optim
import torch.nn as nn

# Are we using our GPU?
print("GPU available: {}".format(torch.cuda.is_available()))
device = 'cuda' #'cpu' if no GPU available
# Out:
# GPU available: False

# %% [markdown]
# ### **Our Data Transform**

# %%
# Transform to a PyTorch tensors and the normalize our valeus between -1 and +1
transform = transforms.Compose([transforms.ToTensor(),
                               transforms.Normalize((0.5, ), (0.5, )) ])

# %%
# Load our Training Data and specify what transform to use when loading
trainset = torchvision.datasets.FashionMNIST(root='./data', train=True,
                                        download=True, transform=transform)

# Load our Test Data and specify what transform to use when loading
testset = torchvision.datasets.FashionMNIST(root='./data', train=False,
                                       download=True, transform=transform)

# %%
# Prepare train and test loader
trainloader = torch.utils.data.DataLoader(trainset, batch_size=32,
                                          shuffle=True, num_workers=2)

testloader = torch.utils.data.DataLoader(testset, batch_size=32,
                                         shuffle=False, num_workers=2)

# Create a list with our class names
classes = ('T-shirt/top', 'Trouser', 'Pullover', 'Dress',
           'Coat', 'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot')

# %%
# We have 60,000 Image samples for our training data & 10,000 for our test data
# each 28 x 28 pixels, as they are grayscale, there is no 3rd dimension to our image
print(trainset.data.shape)
print(testset.data.shape)
# Out:
# torch.Size([60000, 28, 28])
# torch.Size([10000, 28, 28])

# %% [markdown]
# ### **Visualising Our Data**

# %%
# Let's view the 50 first images of the MNIST training dataset
import matplotlib.pyplot as plt

figure = plt.figure()
num_of_images = 50

for index in range(1, num_of_images + 1):
    plt.subplot(5, 10, index)
    plt.axis('off')
    plt.imshow(trainset.data[index], cmap='gray_r')

# %%
import matplotlib.pyplot as plt
import numpy as np
import torchvision.utils

# function to show an image
def imshow(img):
    img = img / 2 + 0.5     # unnormalize
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()

# get some random training images
dataiter = iter(trainloader)
images, labels = next(dataiter)  # Use next() instead of .next()

# show images
imshow(torchvision.utils.make_grid(images))

# print labels
print(' '.join('%5s' % classes[labels[j]] for j in range(8)))
# Out:
# Sneaker Dress Sneaker T-shirt/top Shirt Dress Sandal Sneaker

# %%
import matplotlib.pyplot as plt
import numpy as np
import torchvision.utils

# function to show an image
def imshow(img):
    img = img / 2 + 0.5     # unnormalize
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()

# get some random training images
dataiter = iter(trainloader)
images, labels = next(dataiter)  # Use next() instead of .next()

# show images
imshow(torchvision.utils.make_grid(images))

# print labels
print(' '.join('%5s' % classes[labels[j]] for j in range(8)))
# Out:
# Dress T-shirt/top   Bag Shirt Dress Sneaker Ankle boot Trouser

# %% [markdown]
# # **2. Building and Training Our Simple CNN with No Regularisation**
#
# #### **Defining Our Model**

# %%
# Determine the device with comprehensive checking
def get_device():
    if torch.cuda.is_available():
        try:
            # Additional check for CUDA device
            torch.cuda.current_device()
            print(f"CUDA is available. Using GPU: {torch.cuda.get_device_name(0)}")
            return torch.device('cuda')
        except RuntimeError:
            print("CUDA is reported available, but device initialization failed. Falling back to CPU.")
            return torch.device('cpu')
    else:
        print("CUDA is not available. Using CPU.")
        return torch.device('cpu')

# Select device
device = get_device()

# Create model and move to device
net = Net()
net = net.to(device)
# Out:
# CUDA is not available. Using CPU.

# %%
import torch.nn as nn
import torch.nn.functional as F

class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(1, 32, 3)
        self.conv2 = nn.Conv2d(32, 64, 3)
        self.pool = nn.MaxPool2d(2, 2)
        self.fc1 = nn.Linear(64 * 12 * 12, 128)
        self.fc2 = nn.Linear(128, 10)

    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = self.pool(F.relu(self.conv2(x)))
        x = x.view(-1, 64 * 12 * 12)
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return x


net = Net()
net.to(device)
# Out:
# Net(
#   (conv1): Conv2d(1, 32, kernel_size=(3, 3), stride=(1, 1))
#   (conv2): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1))
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc1): Linear(in_features=9216, out_features=128, bias=True)
#   (fc2): Linear(in_features=128, out_features=10, bias=True)
# )

# %% [markdown]
# #### **Defining our Loss and Optimisation Functions**

# %%
# We import our optimizer function
import torch.optim as optim

# We use Cross Entropy Loss as our loss function
criterion = nn.CrossEntropyLoss()

# For our gradient descent algorthim or Optimizer
# We use Stochastic Gradient Descent (SGD) with a learning rate of 0.001
# We set the momentum to be 0.9
optimizer = optim.SGD(net.parameters(), lr=0.001, momentum=0.9)

# %% [markdown]
# # **3. Training Our Model**

# %%
# We loop over the traing dataset multiple times (each time is called an epoch)
epochs = 15

# Create some empty arrays to store logs
epoch_log = []
loss_log = []
accuracy_log = []

# Iterate for a specified number of epochs
for epoch in range(epochs):
    print(f'Starting Epoch: {epoch+1}...')

    # We keep adding or accumulating our loss after each mini-batch in running_loss
    running_loss = 0.0

    # We iterate through our trainloader iterator
    # Each cycle is a minibatch
    for i, data in enumerate(trainloader, 0):
        # get the inputs; data is a list of [inputs, labels]
        inputs, labels = data

        # Move our data to GPU
        inputs = inputs.to(device)
        labels = labels.to(device)

        # Clear the gradients before training by setting to zero
        # Required for a fresh start
        optimizer.zero_grad()

        # Forward -> backprop + optimize
        outputs = net(inputs) # Forward Propagation
        loss = criterion(outputs, labels) # Get Loss (quantify the difference between the results and predictions)
        loss.backward() # Back propagate to obtain the new gradients for all nodes
        optimizer.step() # Update the gradients/weights

        # Print Training statistics - Epoch/Iterations/Loss/Accurachy
        running_loss += loss.item()
        if i % 100 == 99:    # show our loss every 50 mini-batches
            correct = 0 # Initialize our variable to hold the count for the correct predictions
            total = 0 # Initialize our variable to hold the count of the number of labels iterated

            # We don't need gradients for validation, so wrap in
            # no_grad to save memory
            with torch.no_grad():
                # Iterate through the testloader iterator
                for data in testloader:
                    images, labels = data
                    # Move our data to GPU
                    images = images.to(device)
                    labels = labels.to(device)

                    # Foward propagate our test data batch through our model
                    outputs = net(images)

                     # Get predictions from the maximum value
                    _, predicted = torch.max(outputs.data, 1)
                    # Keep adding the label size or length to the total variable
                    total += labels.size(0)
                    # Keep a running total of the number of predictions predicted correctly
                    correct += (predicted == labels).sum().item()

                accuracy = 100 * correct / total
                epoch_num = epoch + 1
                actual_loss = running_loss / 50
                print(f'Epoch: {epoch_num}, Mini-Batches Completed: {(i+1)}, Loss: {actual_loss:.3f}, Test Accuracy = {accuracy:.3f}%')
                running_loss = 0.0

    # Store training stats after each epoch
    epoch_log.append(epoch_num)
    loss_log.append(actual_loss)
    accuracy_log.append(accuracy)

print('Finished Training')
# Out:
# Starting Epoch: 1...
# Epoch: 1, Mini-Batches Completed: 100, Loss: 3.807, Test Accuracy = 66.770%
# Epoch: 1, Mini-Batches Completed: 200, Loss: 1.780, Test Accuracy = 71.350%
# Epoch: 1, Mini-Batches Completed: 300, Loss: 1.515, Test Accuracy = 74.280%
# Epoch: 1, Mini-Batches Completed: 400, Loss: 1.349, Test Accuracy = 75.280%
# Epoch: 1, Mini-Batches Completed: 500, Loss: 1.257, Test Accuracy = 74.920%
# Epoch: 1, Mini-Batches Completed: 600, Loss: 1.220, Test Accuracy = 76.010%
# Epoch: 1, Mini-Batches Completed: 700, Loss: 1.244, Test Accuracy = 75.800%
# Epoch: 1, Mini-Batches Completed: 800, Loss: 1.223, Test Accuracy = 78.470%
# Epoch: 1, Mini-Batches Completed: 900, Loss: 1.163, Test Accuracy = 76.840%
# Epoch: 1, Mini-Batches Completed: 1000, Loss: 1.105, Test Accuracy = 78.980%
# Epoch: 1, Mini-Batches Completed: 1100, Loss: 1.102, Test Accuracy = 78.060%
# Epoch: 1, Mini-Batches Completed: 1200, Loss: 1.137, Test Accuracy = 79.720%
# Epoch: 1, Mini-Batches Completed: 1300, Loss: 1.076, Test Accuracy = 79.330%
# Epoch: 1, Mini-Batches Completed: 1400, Loss: 1.059, Test Accuracy = 81.050%
# Epoch: 1, Mini-Batches Completed: 1500, Loss: 1.051, Test Accuracy = 78.930%
# Epoch: 1, Mini-Batches Completed: 1600, Loss: 1.031, Test Accuracy = 78.950%
# Epoch: 1, Mini-Batches Completed: 1700, Loss: 0.980, Test Accuracy = 81.380%
# Epoch: 1, Mini-Batches Completed: 1800, Loss: 0.962, Test Accuracy = 81.100%
# Starting Epoch: 2...
# Epoch: 2, Mini-Batches Completed: 100, Loss: 0.966, Test Accuracy = 82.300%
# Epoch: 2, Mini-Batches Completed: 200, Loss: 0.904, Test Accuracy = 81.600%
# Epoch: 2, Mini-Batches Completed: 300, Loss: 0.908, Test Accuracy = 82.690%
# Epoch: 2, Mini-Batches Completed: 400, Loss: 0.954, Test Accuracy = 82.280%
# Epoch: 2, Mini-Batches Completed: 500, Loss: 0.931, Test Accuracy = 81.450%
# Epoch: 2, Mini-Batches Completed: 600, Loss: 0.867, Test Accuracy = 83.620%
# Epoch: 2, Mini-Batches Completed: 700, Loss: 0.906, Test Accuracy = 84.040%
# Epoch: 2, Mini-Batches Completed: 800, Loss: 0.883, Test Accuracy = 84.090%
# Epoch: 2, Mini-Batches Completed: 900, Loss: 0.850, Test Accuracy = 83.030%
# Epoch: 2, Mini-Batches Completed: 1000, Loss: 0.856, Test Accuracy = 84.250%
# Epoch: 2, Mini-Batches Completed: 1100, Loss: 0.811, Test Accuracy = 84.330%
# Epoch: 2, Mini-Batches Completed: 1200, Loss: 0.787, Test Accuracy = 83.500%
# Epoch: 2, Mini-Batches Completed: 1300, Loss: 0.806, Test Accuracy = 84.510%
# Epoch: 2, Mini-Batches Completed: 1400, Loss: 0.880, Test Accuracy = 84.380%
# Epoch: 2, Mini-Batches Completed: 1500, Loss: 0.788, Test Accuracy = 84.090%
# Epoch: 2, Mini-Batches Completed: 1600, Loss: 0.836, Test Accuracy = 83.810%
# Epoch: 2, Mini-Batches Completed: 1700, Loss: 0.809, Test Accuracy = 84.650%
# Epoch: 2, Mini-Batches Completed: 1800, Loss: 0.774, Test Accuracy = 83.330%
# Starting Epoch: 3...
# Epoch: 3, Mini-Batches Completed: 100, Loss: 0.717, Test Accuracy = 84.240%
# Epoch: 3, Mini-Batches Completed: 200, Loss: 0.762, Test Accuracy = 85.190%
# Epoch: 3, Mini-Batches Completed: 300, Loss: 0.807, Test Accuracy = 85.820%
# Epoch: 3, Mini-Batches Completed: 400, Loss: 0.759, Test Accuracy = 85.690%
# Epoch: 3, Mini-Batches Completed: 500, Loss: 0.768, Test Accuracy = 85.950%
# Epoch: 3, Mini-Batches Completed: 600, Loss: 0.794, Test Accuracy = 85.870%
# Epoch: 3, Mini-Batches Completed: 700, Loss: 0.726, Test Accuracy = 83.520%
# Epoch: 3, Mini-Batches Completed: 800, Loss: 0.730, Test Accuracy = 84.780%
# Epoch: 3, Mini-Batches Completed: 900, Loss: 0.733, Test Accuracy = 86.050%
# Epoch: 3, Mini-Batches Completed: 1000, Loss: 0.716, Test Accuracy = 85.690%
# Epoch: 3, Mini-Batches Completed: 1100, Loss: 0.740, Test Accuracy = 85.630%
# Epoch: 3, Mini-Batches Completed: 1200, Loss: 0.732, Test Accuracy = 85.800%
# Epoch: 3, Mini-Batches Completed: 1300, Loss: 0.746, Test Accuracy = 85.290%
# Epoch: 3, Mini-Batches Completed: 1400, Loss: 0.646, Test Accuracy = 86.420%
# Epoch: 3, Mini-Batches Completed: 1500, Loss: 0.706, Test Accuracy = 86.320%
# Epoch: 3, Mini-Batches Completed: 1600, Loss: 0.668, Test Accuracy = 85.860%
# Epoch: 3, Mini-Batches Completed: 1700, Loss: 0.732, Test Accuracy = 86.440%
# Epoch: 3, Mini-Batches Completed: 1800, Loss: 0.672, Test Accuracy = 86.460%
# Starting Epoch: 4...
# Epoch: 4, Mini-Batches Completed: 100, Loss: 0.640, Test Accuracy = 86.650%
# Epoch: 4, Mini-Batches Completed: 200, Loss: 0.642, Test Accuracy = 87.360%
# Epoch: 4, Mini-Batches Completed: 300, Loss: 0.693, Test Accuracy = 86.990%
# Epoch: 4, Mini-Batches Completed: 400, Loss: 0.658, Test Accuracy = 86.320%
# Epoch: 4, Mini-Batches Completed: 500, Loss: 0.693, Test Accuracy = 87.170%
# Epoch: 4, Mini-Batches Completed: 600, Loss: 0.640, Test Accuracy = 86.820%
# Epoch: 4, Mini-Batches Completed: 700, Loss: 0.672, Test Accuracy = 86.920%
# Epoch: 4, Mini-Batches Completed: 800, Loss: 0.691, Test Accuracy = 87.060%
# Epoch: 4, Mini-Batches Completed: 900, Loss: 0.656, Test Accuracy = 87.180%
# Epoch: 4, Mini-Batches Completed: 1000, Loss: 0.672, Test Accuracy = 86.870%
# Epoch: 4, Mini-Batches Completed: 1100, Loss: 0.673, Test Accuracy = 87.640%
# Epoch: 4, Mini-Batches Completed: 1200, Loss: 0.663, Test Accuracy = 85.650%
# Epoch: 4, Mini-Batches Completed: 1300, Loss: 0.636, Test Accuracy = 87.600%
# Epoch: 4, Mini-Batches Completed: 1400, Loss: 0.605, Test Accuracy = 88.020%
# Epoch: 4, Mini-Batches Completed: 1500, Loss: 0.649, Test Accuracy = 87.510%
# Epoch: 4, Mini-Batches Completed: 1600, Loss: 0.602, Test Accuracy = 87.990%
# Epoch: 4, Mini-Batches Completed: 1700, Loss: 0.630, Test Accuracy = 88.150%
# Epoch: 4, Mini-Batches Completed: 1800, Loss: 0.645, Test Accuracy = 87.810%
# Starting Epoch: 5...
# Epoch: 5, Mini-Batches Completed: 100, Loss: 0.640, Test Accuracy = 88.200%
# Epoch: 5, Mini-Batches Completed: 200, Loss: 0.597, Test Accuracy = 88.270%
# Epoch: 5, Mini-Batches Completed: 300, Loss: 0.599, Test Accuracy = 88.220%
# Epoch: 5, Mini-Batches Completed: 400, Loss: 0.655, Test Accuracy = 88.090%
# Epoch: 5, Mini-Batches Completed: 500, Loss: 0.545, Test Accuracy = 88.010%
# Epoch: 5, Mini-Batches Completed: 600, Loss: 0.609, Test Accuracy = 87.710%
# Epoch: 5, Mini-Batches Completed: 700, Loss: 0.560, Test Accuracy = 88.020%
# Epoch: 5, Mini-Batches Completed: 800, Loss: 0.592, Test Accuracy = 87.640%
# Epoch: 5, Mini-Batches Completed: 900, Loss: 0.603, Test Accuracy = 87.640%
# Epoch: 5, Mini-Batches Completed: 1000, Loss: 0.611, Test Accuracy = 87.280%
# Epoch: 5, Mini-Batches Completed: 1100, Loss: 0.616, Test Accuracy = 88.200%
# Epoch: 5, Mini-Batches Completed: 1200, Loss: 0.528, Test Accuracy = 88.720%
# Epoch: 5, Mini-Batches Completed: 1300, Loss: 0.572, Test Accuracy = 88.320%
# Epoch: 5, Mini-Batches Completed: 1400, Loss: 0.601, Test Accuracy = 88.050%
# Epoch: 5, Mini-Batches Completed: 1500, Loss: 0.581, Test Accuracy = 88.080%
# Epoch: 5, Mini-Batches Completed: 1600, Loss: 0.596, Test Accuracy = 87.990%
# Epoch: 5, Mini-Batches Completed: 1700, Loss: 0.597, Test Accuracy = 88.340%
# Epoch: 5, Mini-Batches Completed: 1800, Loss: 0.626, Test Accuracy = 88.700%
# Starting Epoch: 6...
# Epoch: 6, Mini-Batches Completed: 100, Loss: 0.491, Test Accuracy = 88.540%
# Epoch: 6, Mini-Batches Completed: 200, Loss: 0.567, Test Accuracy = 88.460%
# Epoch: 6, Mini-Batches Completed: 300, Loss: 0.511, Test Accuracy = 88.720%
# Epoch: 6, Mini-Batches Completed: 400, Loss: 0.533, Test Accuracy = 88.710%
# Epoch: 6, Mini-Batches Completed: 500, Loss: 0.540, Test Accuracy = 88.970%
# Epoch: 6, Mini-Batches Completed: 600, Loss: 0.534, Test Accuracy = 88.510%
# Epoch: 6, Mini-Batches Completed: 700, Loss: 0.577, Test Accuracy = 88.510%
# Epoch: 6, Mini-Batches Completed: 800, Loss: 0.595, Test Accuracy = 89.010%
# Epoch: 6, Mini-Batches Completed: 900, Loss: 0.580, Test Accuracy = 88.680%
# Epoch: 6, Mini-Batches Completed: 1000, Loss: 0.569, Test Accuracy = 88.670%
# Epoch: 6, Mini-Batches Completed: 1100, Loss: 0.563, Test Accuracy = 88.180%
# Epoch: 6, Mini-Batches Completed: 1200, Loss: 0.579, Test Accuracy = 88.440%
# Epoch: 6, Mini-Batches Completed: 1300, Loss: 0.557, Test Accuracy = 89.130%
# Epoch: 6, Mini-Batches Completed: 1400, Loss: 0.532, Test Accuracy = 88.680%
# Epoch: 6, Mini-Batches Completed: 1500, Loss: 0.574, Test Accuracy = 88.800%
# Epoch: 6, Mini-Batches Completed: 1600, Loss: 0.563, Test Accuracy = 88.190%
# Epoch: 6, Mini-Batches Completed: 1700, Loss: 0.516, Test Accuracy = 89.090%
# Epoch: 6, Mini-Batches Completed: 1800, Loss: 0.526, Test Accuracy = 88.650%
# Starting Epoch: 7...
# Epoch: 7, Mini-Batches Completed: 100, Loss: 0.572, Test Accuracy = 88.930%
# Epoch: 7, Mini-Batches Completed: 200, Loss: 0.525, Test Accuracy = 89.130%
# Epoch: 7, Mini-Batches Completed: 300, Loss: 0.462, Test Accuracy = 88.690%
# Epoch: 7, Mini-Batches Completed: 400, Loss: 0.512, Test Accuracy = 88.710%
# Epoch: 7, Mini-Batches Completed: 500, Loss: 0.520, Test Accuracy = 89.110%
# Epoch: 7, Mini-Batches Completed: 600, Loss: 0.501, Test Accuracy = 88.990%
# Epoch: 7, Mini-Batches Completed: 700, Loss: 0.471, Test Accuracy = 89.270%
# Epoch: 7, Mini-Batches Completed: 800, Loss: 0.525, Test Accuracy = 89.200%
# Epoch: 7, Mini-Batches Completed: 900, Loss: 0.516, Test Accuracy = 89.330%
# Epoch: 7, Mini-Batches Completed: 1000, Loss: 0.536, Test Accuracy = 89.340%
# Epoch: 7, Mini-Batches Completed: 1100, Loss: 0.527, Test Accuracy = 89.190%
# Epoch: 7, Mini-Batches Completed: 1200, Loss: 0.513, Test Accuracy = 89.410%
# Epoch: 7, Mini-Batches Completed: 1300, Loss: 0.499, Test Accuracy = 89.360%
# Epoch: 7, Mini-Batches Completed: 1400, Loss: 0.502, Test Accuracy = 89.030%
# Epoch: 7, Mini-Batches Completed: 1500, Loss: 0.500, Test Accuracy = 88.720%
# Epoch: 7, Mini-Batches Completed: 1600, Loss: 0.546, Test Accuracy = 88.650%
# Epoch: 7, Mini-Batches Completed: 1700, Loss: 0.529, Test Accuracy = 88.940%
# Epoch: 7, Mini-Batches Completed: 1800, Loss: 0.495, Test Accuracy = 89.570%
# Starting Epoch: 8...
# Epoch: 8, Mini-Batches Completed: 100, Loss: 0.508, Test Accuracy = 89.260%
# Epoch: 8, Mini-Batches Completed: 200, Loss: 0.475, Test Accuracy = 89.640%
# Epoch: 8, Mini-Batches Completed: 300, Loss: 0.500, Test Accuracy = 89.650%
# Epoch: 8, Mini-Batches Completed: 400, Loss: 0.500, Test Accuracy = 89.560%
# Epoch: 8, Mini-Batches Completed: 500, Loss: 0.512, Test Accuracy = 89.770%
# Epoch: 8, Mini-Batches Completed: 600, Loss: 0.467, Test Accuracy = 88.720%
# Epoch: 8, Mini-Batches Completed: 700, Loss: 0.445, Test Accuracy = 89.700%
# Epoch: 8, Mini-Batches Completed: 800, Loss: 0.504, Test Accuracy = 89.690%
# Epoch: 8, Mini-Batches Completed: 900, Loss: 0.493, Test Accuracy = 89.720%
# Epoch: 8, Mini-Batches Completed: 1000, Loss: 0.482, Test Accuracy = 89.650%
# Epoch: 8, Mini-Batches Completed: 1100, Loss: 0.475, Test Accuracy = 89.480%
# Epoch: 8, Mini-Batches Completed: 1200, Loss: 0.485, Test Accuracy = 89.450%
# Epoch: 8, Mini-Batches Completed: 1300, Loss: 0.492, Test Accuracy = 89.110%
# Epoch: 8, Mini-Batches Completed: 1400, Loss: 0.489, Test Accuracy = 89.060%
# Epoch: 8, Mini-Batches Completed: 1500, Loss: 0.451, Test Accuracy = 90.040%
# Epoch: 8, Mini-Batches Completed: 1600, Loss: 0.488, Test Accuracy = 89.300%
# Epoch: 8, Mini-Batches Completed: 1700, Loss: 0.466, Test Accuracy = 89.470%
# Epoch: 8, Mini-Batches Completed: 1800, Loss: 0.462, Test Accuracy = 89.880%
# Starting Epoch: 9...
# Epoch: 9, Mini-Batches Completed: 100, Loss: 0.485, Test Accuracy = 89.730%
# Epoch: 9, Mini-Batches Completed: 200, Loss: 0.462, Test Accuracy = 90.110%
# Epoch: 9, Mini-Batches Completed: 300, Loss: 0.425, Test Accuracy = 89.910%
# Epoch: 9, Mini-Batches Completed: 400, Loss: 0.470, Test Accuracy = 89.940%
# Epoch: 9, Mini-Batches Completed: 500, Loss: 0.471, Test Accuracy = 89.540%
# Epoch: 9, Mini-Batches Completed: 600, Loss: 0.434, Test Accuracy = 90.080%
# Epoch: 9, Mini-Batches Completed: 700, Loss: 0.483, Test Accuracy = 89.520%
# Epoch: 9, Mini-Batches Completed: 800, Loss: 0.472, Test Accuracy = 89.920%
# Epoch: 9, Mini-Batches Completed: 900, Loss: 0.441, Test Accuracy = 89.160%
# Epoch: 9, Mini-Batches Completed: 1000, Loss: 0.467, Test Accuracy = 90.080%
# Epoch: 9, Mini-Batches Completed: 1100, Loss: 0.441, Test Accuracy = 90.200%
# Epoch: 9, Mini-Batches Completed: 1200, Loss: 0.450, Test Accuracy = 89.450%
# Epoch: 9, Mini-Batches Completed: 1300, Loss: 0.442, Test Accuracy = 89.390%
# Epoch: 9, Mini-Batches Completed: 1400, Loss: 0.457, Test Accuracy = 90.430%
# Epoch: 9, Mini-Batches Completed: 1500, Loss: 0.442, Test Accuracy = 90.190%
# Epoch: 9, Mini-Batches Completed: 1600, Loss: 0.467, Test Accuracy = 90.060%
# Epoch: 9, Mini-Batches Completed: 1700, Loss: 0.456, Test Accuracy = 90.340%
# Epoch: 9, Mini-Batches Completed: 1800, Loss: 0.472, Test Accuracy = 89.850%
# Starting Epoch: 10...
# Epoch: 10, Mini-Batches Completed: 100, Loss: 0.422, Test Accuracy = 90.110%
# Epoch: 10, Mini-Batches Completed: 200, Loss: 0.447, Test Accuracy = 90.570%
# Epoch: 10, Mini-Batches Completed: 300, Loss: 0.439, Test Accuracy = 90.280%
# Epoch: 10, Mini-Batches Completed: 400, Loss: 0.454, Test Accuracy = 89.890%
# Epoch: 10, Mini-Batches Completed: 500, Loss: 0.424, Test Accuracy = 90.210%
# Epoch: 10, Mini-Batches Completed: 600, Loss: 0.426, Test Accuracy = 89.700%
# Epoch: 10, Mini-Batches Completed: 700, Loss: 0.417, Test Accuracy = 90.270%
# Epoch: 10, Mini-Batches Completed: 800, Loss: 0.421, Test Accuracy = 90.080%
# Epoch: 10, Mini-Batches Completed: 900, Loss: 0.437, Test Accuracy = 90.080%
# Epoch: 10, Mini-Batches Completed: 1000, Loss: 0.422, Test Accuracy = 90.120%
# Epoch: 10, Mini-Batches Completed: 1100, Loss: 0.445, Test Accuracy = 90.330%
# Epoch: 10, Mini-Batches Completed: 1200, Loss: 0.427, Test Accuracy = 89.890%
# Epoch: 10, Mini-Batches Completed: 1300, Loss: 0.428, Test Accuracy = 90.110%
# Epoch: 10, Mini-Batches Completed: 1400, Loss: 0.424, Test Accuracy = 90.410%
# Epoch: 10, Mini-Batches Completed: 1500, Loss: 0.420, Test Accuracy = 89.900%
# Epoch: 10, Mini-Batches Completed: 1600, Loss: 0.460, Test Accuracy = 90.610%
# Epoch: 10, Mini-Batches Completed: 1700, Loss: 0.410, Test Accuracy = 90.350%
# Epoch: 10, Mini-Batches Completed: 1800, Loss: 0.406, Test Accuracy = 89.820%
# Starting Epoch: 11...
# Epoch: 11, Mini-Batches Completed: 100, Loss: 0.402, Test Accuracy = 90.580%
# Epoch: 11, Mini-Batches Completed: 200, Loss: 0.392, Test Accuracy = 89.680%
# Epoch: 11, Mini-Batches Completed: 300, Loss: 0.395, Test Accuracy = 90.280%
# Epoch: 11, Mini-Batches Completed: 400, Loss: 0.410, Test Accuracy = 90.480%
# Epoch: 11, Mini-Batches Completed: 500, Loss: 0.409, Test Accuracy = 90.550%
# Epoch: 11, Mini-Batches Completed: 600, Loss: 0.416, Test Accuracy = 89.270%
# Epoch: 11, Mini-Batches Completed: 700, Loss: 0.385, Test Accuracy = 89.360%
# Epoch: 11, Mini-Batches Completed: 800, Loss: 0.416, Test Accuracy = 90.340%
# Epoch: 11, Mini-Batches Completed: 900, Loss: 0.407, Test Accuracy = 90.470%
# Epoch: 11, Mini-Batches Completed: 1000, Loss: 0.435, Test Accuracy = 89.710%
# Epoch: 11, Mini-Batches Completed: 1100, Loss: 0.384, Test Accuracy = 89.780%
# Epoch: 11, Mini-Batches Completed: 1200, Loss: 0.387, Test Accuracy = 90.470%
# Epoch: 11, Mini-Batches Completed: 1300, Loss: 0.420, Test Accuracy = 90.300%
# Epoch: 11, Mini-Batches Completed: 1400, Loss: 0.407, Test Accuracy = 90.680%
# Epoch: 11, Mini-Batches Completed: 1500, Loss: 0.403, Test Accuracy = 90.630%
# Epoch: 11, Mini-Batches Completed: 1600, Loss: 0.404, Test Accuracy = 90.190%
# Epoch: 11, Mini-Batches Completed: 1700, Loss: 0.429, Test Accuracy = 90.180%
# Epoch: 11, Mini-Batches Completed: 1800, Loss: 0.395, Test Accuracy = 90.540%
# Starting Epoch: 12...
# Epoch: 12, Mini-Batches Completed: 100, Loss: 0.417, Test Accuracy = 90.070%
# Epoch: 12, Mini-Batches Completed: 200, Loss: 0.377, Test Accuracy = 90.160%
# Epoch: 12, Mini-Batches Completed: 300, Loss: 0.417, Test Accuracy = 90.380%
# Epoch: 12, Mini-Batches Completed: 400, Loss: 0.390, Test Accuracy = 90.460%
# Epoch: 12, Mini-Batches Completed: 500, Loss: 0.397, Test Accuracy = 90.900%
# Epoch: 12, Mini-Batches Completed: 600, Loss: 0.343, Test Accuracy = 90.680%
# Epoch: 12, Mini-Batches Completed: 700, Loss: 0.376, Test Accuracy = 90.550%
# Epoch: 12, Mini-Batches Completed: 800, Loss: 0.393, Test Accuracy = 90.380%
# Epoch: 12, Mini-Batches Completed: 900, Loss: 0.415, Test Accuracy = 90.650%
# Epoch: 12, Mini-Batches Completed: 1000, Loss: 0.384, Test Accuracy = 90.710%
# Epoch: 12, Mini-Batches Completed: 1100, Loss: 0.360, Test Accuracy = 90.580%
# Epoch: 12, Mini-Batches Completed: 1200, Loss: 0.405, Test Accuracy = 90.440%
# Epoch: 12, Mini-Batches Completed: 1300, Loss: 0.402, Test Accuracy = 91.040%
# Epoch: 12, Mini-Batches Completed: 1400, Loss: 0.364, Test Accuracy = 90.460%
# Epoch: 12, Mini-Batches Completed: 1500, Loss: 0.356, Test Accuracy = 90.900%
# Epoch: 12, Mini-Batches Completed: 1600, Loss: 0.371, Test Accuracy = 90.530%
# Epoch: 12, Mini-Batches Completed: 1700, Loss: 0.409, Test Accuracy = 90.410%
# Epoch: 12, Mini-Batches Completed: 1800, Loss: 0.410, Test Accuracy = 90.720%
# Starting Epoch: 13...
# Epoch: 13, Mini-Batches Completed: 100, Loss: 0.378, Test Accuracy = 90.810%
# Epoch: 13, Mini-Batches Completed: 200, Loss: 0.349, Test Accuracy = 90.680%
# Epoch: 13, Mini-Batches Completed: 300, Loss: 0.349, Test Accuracy = 90.700%
# Epoch: 13, Mini-Batches Completed: 400, Loss: 0.361, Test Accuracy = 90.840%
# Epoch: 13, Mini-Batches Completed: 500, Loss: 0.367, Test Accuracy = 90.410%
# Epoch: 13, Mini-Batches Completed: 600, Loss: 0.359, Test Accuracy = 90.420%
# Epoch: 13, Mini-Batches Completed: 700, Loss: 0.340, Test Accuracy = 90.970%
# Epoch: 13, Mini-Batches Completed: 800, Loss: 0.400, Test Accuracy = 89.680%
# Epoch: 13, Mini-Batches Completed: 900, Loss: 0.359, Test Accuracy = 90.860%
# Epoch: 13, Mini-Batches Completed: 1000, Loss: 0.342, Test Accuracy = 91.130%
# Epoch: 13, Mini-Batches Completed: 1100, Loss: 0.371, Test Accuracy = 90.770%
# Epoch: 13, Mini-Batches Completed: 1200, Loss: 0.408, Test Accuracy = 91.210%
# Epoch: 13, Mini-Batches Completed: 1300, Loss: 0.390, Test Accuracy = 90.580%
# Epoch: 13, Mini-Batches Completed: 1400, Loss: 0.343, Test Accuracy = 91.110%
# Epoch: 13, Mini-Batches Completed: 1500, Loss: 0.357, Test Accuracy = 90.920%
# Epoch: 13, Mini-Batches Completed: 1600, Loss: 0.392, Test Accuracy = 91.180%
# Epoch: 13, Mini-Batches Completed: 1700, Loss: 0.337, Test Accuracy = 91.270%
# Epoch: 13, Mini-Batches Completed: 1800, Loss: 0.405, Test Accuracy = 91.080%
# Starting Epoch: 14...
# Epoch: 14, Mini-Batches Completed: 100, Loss: 0.348, Test Accuracy = 91.300%
# Epoch: 14, Mini-Batches Completed: 200, Loss: 0.340, Test Accuracy = 90.900%
# Epoch: 14, Mini-Batches Completed: 300, Loss: 0.347, Test Accuracy = 90.650%
# Epoch: 14, Mini-Batches Completed: 400, Loss: 0.331, Test Accuracy = 90.790%
# Epoch: 14, Mini-Batches Completed: 500, Loss: 0.311, Test Accuracy = 91.200%
# Epoch: 14, Mini-Batches Completed: 600, Loss: 0.323, Test Accuracy = 90.720%
# Epoch: 14, Mini-Batches Completed: 700, Loss: 0.399, Test Accuracy = 90.330%
# Epoch: 14, Mini-Batches Completed: 800, Loss: 0.324, Test Accuracy = 91.070%
# Epoch: 14, Mini-Batches Completed: 900, Loss: 0.337, Test Accuracy = 91.290%
# Epoch: 14, Mini-Batches Completed: 1000, Loss: 0.372, Test Accuracy = 91.310%
# Epoch: 14, Mini-Batches Completed: 1100, Loss: 0.360, Test Accuracy = 91.020%
# Epoch: 14, Mini-Batches Completed: 1200, Loss: 0.354, Test Accuracy = 91.100%
# Epoch: 14, Mini-Batches Completed: 1300, Loss: 0.362, Test Accuracy = 90.780%
# Epoch: 14, Mini-Batches Completed: 1400, Loss: 0.343, Test Accuracy = 90.690%
# Epoch: 14, Mini-Batches Completed: 1500, Loss: 0.362, Test Accuracy = 90.810%
# Epoch: 14, Mini-Batches Completed: 1600, Loss: 0.341, Test Accuracy = 91.080%
# Epoch: 14, Mini-Batches Completed: 1700, Loss: 0.355, Test Accuracy = 90.890%
# Epoch: 14, Mini-Batches Completed: 1800, Loss: 0.355, Test Accuracy = 91.020%
# Starting Epoch: 15...
# Epoch: 15, Mini-Batches Completed: 100, Loss: 0.310, Test Accuracy = 90.950%
# Epoch: 15, Mini-Batches Completed: 200, Loss: 0.327, Test Accuracy = 90.310%
# Epoch: 15, Mini-Batches Completed: 300, Loss: 0.327, Test Accuracy = 90.760%
# Epoch: 15, Mini-Batches Completed: 400, Loss: 0.313, Test Accuracy = 90.600%
# Epoch: 15, Mini-Batches Completed: 500, Loss: 0.300, Test Accuracy = 90.980%
# Epoch: 15, Mini-Batches Completed: 600, Loss: 0.329, Test Accuracy = 90.700%
# Epoch: 15, Mini-Batches Completed: 700, Loss: 0.347, Test Accuracy = 91.010%
# Epoch: 15, Mini-Batches Completed: 800, Loss: 0.346, Test Accuracy = 91.080%
# Epoch: 15, Mini-Batches Completed: 900, Loss: 0.325, Test Accuracy = 91.320%
# Epoch: 15, Mini-Batches Completed: 1000, Loss: 0.340, Test Accuracy = 91.210%
# Epoch: 15, Mini-Batches Completed: 1100, Loss: 0.323, Test Accuracy = 91.100%
# Epoch: 15, Mini-Batches Completed: 1200, Loss: 0.362, Test Accuracy = 91.190%
# Epoch: 15, Mini-Batches Completed: 1300, Loss: 0.293, Test Accuracy = 90.880%
# Epoch: 15, Mini-Batches Completed: 1400, Loss: 0.338, Test Accuracy = 91.270%
# Epoch: 15, Mini-Batches Completed: 1500, Loss: 0.320, Test Accuracy = 90.530%
# Epoch: 15, Mini-Batches Completed: 1600, Loss: 0.359, Test Accuracy = 91.310%
# Epoch: 15, Mini-Batches Completed: 1700, Loss: 0.344, Test Accuracy = 90.920%
# Epoch: 15, Mini-Batches Completed: 1800, Loss: 0.338, Test Accuracy = 91.380%
# Finished Training

# %% [markdown]
# #### **Our Model's Accuracy**

# %%
correct = 0
total = 0

with torch.no_grad():
    for data in testloader:
        images, labels = data
        # Move our data to GPU
        images = images.to(device)
        labels = labels.to(device)
        outputs = net(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

accuracy = 100 * correct / total
print(f'Accuracy of the network on the 10000 test images: {accuracy:.4}%')
# Out:
# Accuracy of the network on the 10000 test images: 91.5%

# %% [markdown]
# #### **Our Training Plots**

# %%
# To create a plot with secondary y-axis we need to create a subplot
fig, ax1 = plt.subplots()

# Set title and x-axis label rotation
plt.title("Accuracy & Loss vs Epoch Mini-Batches")
plt.xticks(rotation=45)

# We use twinx to create a plot a secondary y axis
ax2 = ax1.twinx()

# Create plot for loss_log and accuracy_log
ax1.plot(epoch_log, loss_log, 'g-')
ax2.plot(epoch_log, accuracy_log, 'b-')

# Set labels
ax1.set_xlabel('Epochs')
ax1.set_ylabel('Loss', color='g')
ax2.set_ylabel('Test Accuracy', color='b')

plt.show()

# %% [markdown]
# #### **Saving Our Model's Weights**

# %%
PATH = './fashion_mnist_cnn_net.pth'
torch.save(net.state_dict(), PATH)

# %% [markdown]
# # **4. Data Augumentation**
#
# To introduce Data Augmentation to our training data we simply create new Transform functions.
#
# **Recall our previous transformation function**
#
# ```transform = transforms.Compose([transforms.ToTensor(),
#                                transforms.Normalize((0.5, ), (0.5, )) ])```
#
# ### **We are going to firstly demonstrate how Data Augmentation Affects Our Images**

# %%
# We import PIL, an Image Processing library to implement random rotations
import PIL

data_aug_transform = transforms.Compose([
        transforms.RandomAffine(degrees = 10, translate = (0.05,0.05), shear = 5),
        transforms.ColorJitter(hue = .05, saturation = .05),
        transforms.RandomHorizontalFlip(),
        transforms.RandomRotation(15),
        transforms.Grayscale(num_output_channels = 1)
])

# %% [markdown]
# #### **Perform the Data Augmentatin on a Single Image using the function below to Visualize the effects**

# %%
from matplotlib.pyplot import figure, imshow, axis
from matplotlib.image import imread

def showAugmentations(image, augmentations = 6):
    fig = figure()
    for i in range(augmentations):
        a = fig.add_subplot(1,augmentations,i+1)
        img = data_aug_transform(image)
        imshow(img ,cmap='Greys_r')
        axis('off')

# %%
# Load the first Image from our training data as a numpy array
image = trainset.data[0].numpy()

# Convert it to PIL image's format
img_pil = PIL.Image.fromarray(image)

showAugmentations(img_pil, 8)
