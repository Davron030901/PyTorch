# %% [markdown]
# <a href="https://colab.research.google.com/github/Davron030901/PyTorch/blob/main/22_Keras_Using_CNN_s_as_a_Feature_Extractor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Keras Cats vs Dogs - Feature Extraction**
#
# ---
#
# In this lesson, we learn how to use a pretrained network as a feature extractor. We'll then use those feautres as the input for our Logistic Regression Clasifier.
# 1. Download and Explore our data
# 2. Load our pretrained VGG16 Model
# 3. Extract our Features using VGG16
# 4. Train a LR Classifier using those features
# 5. Test some inferences
#
# ### **You will need to use High-RAM and GPU (for speed increase).**
#
# ![](https://github.com/rajeevratan84/ModernComputerVision/raw/main/Screenshot%202021-05-17%20at%207.55.52%20pm.png)
#
# ![](https://github.com/rajeevratan84/ModernComputerVision/raw/main/Screenshot%202021-05-17%20at%207.57.25%20pm.png)

# %% [markdown]
# ## **1. Download and Explore our data**

# %%
import numpy as np
import os
import pandas as pd
import matplotlib.pyplot as plt
import random
import time
import gc  # Garbage collector uchun
from tensorflow.keras.preprocessing.image import img_to_array, load_img
from tensorflow.keras.applications import VGG16, imagenet_utils
from tensorflow.keras.applications.vgg16 import preprocess_input
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %%
# !gdown --id 1Dvw0UpvItjig0JbnzbTgYKB-ibMrXdxk
# !unzip -q dogs-vs-cats.zip
# !unzip -q train.zip
# !unzip -q test1.zip

# %% [markdown]
# ### **Loading our data and it's labels into a dataframe**
#
# There are many ways we can do this, this way is relatively simple to follow.

# %%
# Fayllarni va ularning kategoriyalarini olish
filenames = os.listdir("./train")
categories = []

for filename in filenames:
    category = filename.split('.')[0]
    if category == 'dog':
        categories.append(1)
    else:
        categories.append(0)

# %%
# Rasm yo'llarini to'liq yaratish
image_paths = ["./train/" + filename for filename in filenames]
labels = categories
print(f"Jami rasmlar: {len(image_paths)}")
# Out:
# Jami rasmlar: 25000

# %% [markdown]
# ## **2. Load our pretrained VGG16 Model**

# %%
# VGG16 modelini yuklash
model = VGG16(weights="imagenet", include_top=False)
print("VGG16 modeli yuklandi")
# Out:
# VGG16 modeli yuklandi

# %%
model.summary()
# Out:
# Model: "vgg16"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, None, None, 3)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv1 (Conv2D)           │ (None, None, None, 64) │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv2 (Conv2D)           │ (None, None, None, 64) │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_pool (MaxPooling2D)      │ (None, None, None, 64) │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv1 (Conv2D)           │ (None, None, None,     │        73,856 │
# │                                 │ 128)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv2 (Conv2D)           │ (None, None, None,     │       147,584 │
# │                                 │ 128)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_pool (MaxPooling2D)      │ (None, None, None,     │             0 │
# │                                 │ 128)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv1 (Conv2D)           │ (None, None, None,     │       295,168 │
# │                                 │ 256)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv2 (Conv2D)           │ (None, None, None,     │       590,080 │
# │                                 │ 256)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv3 (Conv2D)           │ (None, None, None,     │       590,080 │
# │                                 │ 256)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_pool (MaxPooling2D)      │ (None, None, None,     │             0 │
# │                                 │ 256)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv1 (Conv2D)           │ (None, None, None,     │     1,180,160 │
# │                                 │ 512)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv2 (Conv2D)           │ (None, None, None,     │     2,359,808 │
# │                                 │ 512)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv3 (Conv2D)           │ (None, None, None,     │     2,359,808 │
# │                                 │ 512)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_pool (MaxPooling2D)      │ (None, None, None,     │             0 │
# │                                 │ 512)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv1 (Conv2D)           │ (None, None, None,     │     2,359,808 │
# │                                 │ 512)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv2 (Conv2D)           │ (None, None, None,     │     2,359,808 │
# │                                 │ 512)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv3 (Conv2D)           │ (None, None, None,     │     2,359,808 │
# │                                 │ 512)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_pool (MaxPooling2D)      │ (None, None, None,     │             0 │
# │                                 │ 512)                   │               │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 14,714,688 (56.13 MB)
#  Trainable params: 14,714,688 (56.13 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## **What exactly are we doing?**
#
# We're taking the output of the last CONV-POOL layer (see below).
#
# The output shape at this layer is **7 x 7 x 512**
#
# ![feat_extraction](https://appliedmachinelearning.files.wordpress.com/2021/05/ef54e-vgg16.png?w=612&zoom=2)
# Image referenced from [here](https://appliedmachinelearning.blog/2019/07/29/transfer-learning-using-feature-extraction-from-trained-models-food-images-classification/)

# %%
# Xotirani tejash parametrlari
batch_size = 64  # Kichikroq batch hajmi
save_interval = 10  # Har qancha batch dan keyin diskga saqlaymiz

# %%
# Batchlarni hisoblash
total_batches = len(image_paths) // batch_size
if len(image_paths) % batch_size != 0:
    total_batches += 1

print(f"Jami batchlar: {total_batches}")
print(f"Har {save_interval} batchdan keyin diskga saqlanadi")
# Out:
# Jami batchlar: 391
# Har 10 batchdan keyin diskga saqlanadi

# %% [markdown]
# ### **Store our Image Paths and Label names**

# %%
# Har bir batch uchun features va labels uchun fayl nomlari
feature_files = []
label_files = []

# Xususiyatlarni ajratish va diskga saqlash
start_time = time.time()

# %% [markdown]
# ## **3. Extract our Features using VGG16**

# %%
for batch_idx in range(0, total_batches):
    batch_start = time.time()

    # Joriy batch uchun indekslarni aniqlash
    start_idx = batch_idx * batch_size
    end_idx = min((batch_idx + 1) * batch_size, len(image_paths))

    # Batch ma'lumotlarini olish
    batch_paths = image_paths[start_idx:end_idx]
    batch_labels = labels[start_idx:end_idx]
    batch_images = []
    valid_indices = []

    print(f"\nBatch {batch_idx+1}/{total_batches} qayta ishlanmoqda, {len(batch_paths)} ta rasm")

    # Har bir rasmni qayta ishlash
    for i, image_path in enumerate(batch_paths):
        try:
            # Rasmni yuklash va o'lchamini o'zgartirish
            image = load_img(image_path, target_size=(224, 224))
            image = img_to_array(image)

            # VGG16 uchun rasmni tayyorlash
            image = np.expand_dims(image, axis=0)
            image = preprocess_input(image)

            # Rasmni batch ga qo'shish
            batch_images.append(image)
            valid_indices.append(i)
        except Exception as e:
            print(f"Xatolik: {image_path}: {str(e)}")

    if not batch_images:
        print(f"Batch {batch_idx+1} bo'sh edi")
        continue

    # Rasmlarni birlashtirib batch hosil qilish
    batch_images = np.vstack(batch_images)

    # Xususiyatlarni ajratish
    features = model.predict(batch_images, batch_size=len(batch_images), verbose=0)

    # Xususiyatlarni qayta shakllantirish
    features = features.reshape(features.shape[0], -1)

    # Valid labellarga mos keladigan xususiyatlarni va labellarni saqlash
    valid_batch_labels = [batch_labels[idx] for idx in valid_indices]

    # Vaqtda qancha ketganini ko'rsatish
    batch_end = time.time()
    batch_time = batch_end - batch_start
    elapsed = batch_end - start_time
    remaining = (batch_time * (total_batches - (batch_idx + 1)))

    print(f"Batch {batch_idx+1} tugadi. Vaqt: {batch_time:.2f}s")
    print(f"O'tgan vaqt: {elapsed/60:.2f} min. Taxminiy qolgan vaqt: {remaining/60:.2f} min")

    # Xotiradan tozalash
    batch_images = None
    gc.collect()

    # Har bir save_interval da diskga saqlash
    if (batch_idx + 1) % save_interval == 0 or batch_idx == total_batches - 1:
        feature_file = f"features_batch_{batch_idx//save_interval}.npy"
        label_file = f"labels_batch_{batch_idx//save_interval}.npy"

        np.save(feature_file, features)
        np.save(label_file, np.array(valid_batch_labels))

        feature_files.append(feature_file)
        label_files.append(label_file)

        print(f"Xususiyatlar va yorliqlar saqlandi: {feature_file}, {label_file}")

    # Xotiradan tozalash
    features = None
    valid_batch_labels = None
    gc.collect()
# Out:
# Batch 1/391 qayta ishlanmoqda, 64 ta rasm
# Batch 1 tugadi. Vaqt: 20.90s
# O'tgan vaqt: 0.42 min. Taxminiy qolgan vaqt: 135.88 min
#
# Batch 2/391 qayta ishlanmoqda, 64 ta rasm
# Batch 2 tugadi. Vaqt: 0.60s
# O'tgan vaqt: 1.34 min. Taxminiy qolgan vaqt: 3.91 min
#
# Batch 3/391 qayta ishlanmoqda, 64 ta rasm
# Batch 3 tugadi. Vaqt: 0.54s
# O'tgan vaqt: 1.36 min. Taxminiy qolgan vaqt: 3.48 min
#
# Batch 4/391 qayta ishlanmoqda, 64 ta rasm
# Batch 4 tugadi. Vaqt: 0.87s
# O'tgan vaqt: 1.38 min. Taxminiy qolgan vaqt: 5.60 min
#
# Batch 5/391 qayta ishlanmoqda, 64 ta rasm
# Batch 5 tugadi. Vaqt: 0.96s
# O'tgan vaqt: 1.40 min. Taxminiy qolgan vaqt: 6.18 min
#
# Batch 6/391 qayta ishlanmoqda, 64 ta rasm
# Batch 6 tugadi. Vaqt: 0.57s
# O'tgan vaqt: 1.42 min. Taxminiy qolgan vaqt: 3.68 min
#
# Batch 7/391 qayta ishlanmoqda, 64 ta rasm
# Batch 7 tugadi. Vaqt: 0.55s
# O'tgan vaqt: 1.44 min. Taxminiy qolgan vaqt: 3.53 min
#
# Batch 8/391 qayta ishlanmoqda, 64 ta rasm
# Batch 8 tugadi. Vaqt: 0.86s
# O'tgan vaqt: 1.46 min. Taxminiy qolgan vaqt: 5.47 min
#
# Batch 9/391 qayta ishlanmoqda, 64 ta rasm
# Batch 9 tugadi. Vaqt: 0.98s
# O'tgan vaqt: 1.48 min. Taxminiy qolgan vaqt: 6.27 min
#
# Batch 10/391 qayta ishlanmoqda, 64 ta rasm
# Batch 10 tugadi. Vaqt: 1.62s
# O'tgan vaqt: 1.53 min. Taxminiy qolgan vaqt: 10.31 min
# Xususiyatlar va yorliqlar saqlandi: features_batch_0.npy, labels_batch_0.npy
#
# Batch 11/391 qayta ishlanmoqda, 64 ta rasm
# Batch 11 tugadi. Vaqt: 0.67s
# O'tgan vaqt: 1.55 min. Taxminiy qolgan vaqt: 4.26 min
#
# Batch 12/391 qayta ishlanmoqda, 64 ta rasm
# Batch 12 tugadi. Vaqt: 0.57s
# O'tgan vaqt: 1.57 min. Taxminiy qolgan vaqt: 3.58 min
#
# Batch 13/391 qayta ishlanmoqda, 64 ta rasm
# Batch 13 tugadi. Vaqt: 0.56s
# O'tgan vaqt: 1.58 min. Taxminiy qolgan vaqt: 3.53 min
#
# Batch 14/391 qayta ishlanmoqda, 64 ta rasm
# Batch 14 tugadi. Vaqt: 0.85s
# O'tgan vaqt: 1.60 min. Taxminiy qolgan vaqt: 5.37 min
#
# Batch 15/391 qayta ishlanmoqda, 64 ta rasm
# Batch 15 tugadi. Vaqt: 0.87s
# O'tgan vaqt: 1.62 min. Taxminiy qolgan vaqt: 5.48 min
#
# Batch 16/391 qayta ishlanmoqda, 64 ta rasm
# Batch 16 tugadi. Vaqt: 0.56s
# O'tgan vaqt: 1.64 min. Taxminiy qolgan vaqt: 3.50 min
#
# Batch 17/391 qayta ishlanmoqda, 64 ta rasm
# Batch 17 tugadi. Vaqt: 0.86s
# O'tgan vaqt: 1.66 min. Taxminiy qolgan vaqt: 5.38 min
#
# Batch 18/391 qayta ishlanmoqda, 64 ta rasm
# Batch 18 tugadi. Vaqt: 0.55s
# O'tgan vaqt: 1.67 min. Taxminiy qolgan vaqt: 3.41 min
#
# Batch 19/391 qayta ishlanmoqda, 64 ta rasm
# Batch 19 tugadi. Vaqt: 0.58s
# O'tgan vaqt: 1.69 min. Taxminiy qolgan vaqt: 3.57 min
#
# Batch 20/391 qayta ishlanmoqda, 64 ta rasm
# Batch 20 tugadi. Vaqt: 0.97s
# O'tgan vaqt: 1.71 min. Taxminiy qolgan vaqt: 5.99 min
# Xususiyatlar va yorliqlar saqlandi: features_batch_1.npy, labels_batch_1.npy
#
# Batch 21/391 qayta ishlanmoqda, 64 ta rasm
# Batch 21 tugadi. Vaqt: 0.97s
# O'tgan vaqt: 1.74 min. Taxminiy qolgan vaqt: 6.00 min
#
# Batch 22/391 qayta ishlanmoqda, 64 ta rasm
# Batch 22 tugadi. Vaqt: 0.55s
# O'tgan vaqt: 1.75 min. Taxminiy qolgan vaqt: 3.40 min
#
# Batch 23/391 qayta ishlanmoqda, 64 ta rasm
# Batch 23 tugadi. Vaqt: 0.55s
# O'tgan vaqt: 1.77 min. Taxminiy qolgan vaqt: 3.37 min
#
# Batch 24/391 qayta ishlanmoqda, 64 ta rasm
# Batch 24 tugadi. Vaqt: 0.56s
# O'tgan vaqt: 1.78 min. Taxminiy qolgan vaqt: 3.40 min
#
# Batch 25/391 qayta ishlanmoqda, 64 ta rasm
# Batch 25 tugadi. Vaqt: 0.98s
# O'tgan vaqt: 1.80 min. Taxminiy qolgan vaqt: 5.99 min
#
# Batch 26/391 qayta ishlanmoqda, 64 ta rasm
# Batch 26 tugadi. Vaqt: 0.62s
# O'tgan vaqt: 1.82 min. Taxminiy qolgan vaqt: 3.80 min
#
# Batch 27/391 qayta ishlanmoqda, 64 ta rasm
# Batch 27 tugadi. Vaqt: 0.57s
# O'tgan vaqt: 1.84 min. Taxminiy qolgan vaqt: 3.48 min
#
# Batch 28/391 qayta ishlanmoqda, 64 ta rasm
# Batch 28 tugadi. Vaqt: 0.55s
# O'tgan vaqt: 1.85 min. Taxminiy qolgan vaqt: 3.35 min
#
# Batch 29/391 qayta ishlanmoqda, 64 ta rasm
# Batch 29 tugadi. Vaqt: 0.86s
# O'tgan vaqt: 1.87 min. Taxminiy qolgan vaqt: 5.18 min
#
# Batch 30/391 qayta ishlanmoqda, 64 ta rasm
# Batch 30 tugadi. Vaqt: 0.56s
# O'tgan vaqt: 1.89 min. Taxminiy qolgan vaqt: 3.38 min
# Xususiyatlar va yorliqlar saqlandi: features_batch_2.npy, labels_batch_2.npy
#
# Batch 31/391 qayta ishlanmoqda, 64 ta rasm
# Batch 31 tugadi. Vaqt: 0.89s
# O'tgan vaqt: 1.91 min. Taxminiy qolgan vaqt: 5.34 min
#
# Batch 32/391 qayta ishlanmoqda, 64 ta rasm
# Batch 32 tugadi. Vaqt: 1.30s
# O'tgan vaqt: 1.94 min. Taxminiy qolgan vaqt: 7.76 min
#
# Batch 33/391 qayta ishlanmoqda, 64 ta rasm
# Batch 33 tugadi. Vaqt: 0.92s
# O'tgan vaqt: 1.97 min. Taxminiy qolgan vaqt: 5.46 min
#
# Batch 34/391 qayta ishlanmoqda, 64 ta rasm
# Batch 34 tugadi. Vaqt: 0.61s
# O'tgan vaqt: 1.99 min. Taxminiy qolgan vaqt: 3.65 min
#
# Batch 35/391 qayta ishlanmoqda, 64 ta rasm
# Batch 35 tugadi. Vaqt: 0.57s
# O'tgan vaqt: 2.00 min. Taxminiy qolgan vaqt: 3.37 min
#
# Batch 36/391 qayta ishlanmoqda, 64 ta rasm
# Batch 36 tugadi. Vaqt: 0.90s
# O'tgan vaqt: 2.02 min. Taxminiy qolgan vaqt: 5.33 min
#
# Batch 37/391 qayta ishlanmoqda, 64 ta rasm
# Batch 37 tugadi. Vaqt: 0.63s
# O'tgan vaqt: 2.04 min. Taxminiy qolgan vaqt: 3.72 min
#
# Batch 38/391 qayta ishlanmoqda, 64 ta rasm
# Batch 38 tugadi. Vaqt: 0.56s
# O'tgan vaqt: 2.06 min. Taxminiy qolgan vaqt: 3.29 min
#
# Batch 39/391 qayta ishlanmoqda, 64 ta rasm
# Batch 39 tugadi. Vaqt: 1.02s
# O'tgan vaqt: 2.08 min. Taxminiy qolgan vaqt: 5.99 min
#
# Batch 40/391 qayta ishlanmoqda, 64 ta rasm
# Batch 40 tugadi. Vaqt: 1.02s
# O'tgan vaqt: 2.11 min. Taxminiy qolgan vaqt: 5.99 min
# Xususiyatlar va yorliqlar saqlandi: features_batch_3.npy, labels_batch_3.npy
#
# Batch 41/391 qayta ishlanmoqda, 64 ta rasm
# Batch 41 tugadi. Vaqt: 1.23s
# O'tgan vaqt: 2.14 min. Taxminiy qolgan vaqt: 7.17 min
#
# Batch 42/391 qayta ishlanmoqda, 64 ta rasm
# Batch 42 tugadi. Vaqt: 0.98s
# O'tgan vaqt: 2.17 min. Taxminiy qolgan vaqt: 5.68 min
#
# Batch 43/391 qayta ishlanmoqda, 64 ta rasm
# Batch 43 tugadi. Vaqt: 0.55s
# O'tgan vaqt: 2.18 min. Taxminiy qolgan vaqt: 3.21 min
#
# Batch 44/391 qayta ishlanmoqda, 64 ta rasm
# Batch 44 tugadi. Vaqt: 0.88s
# O'tgan vaqt: 2.20 min. Taxminiy qolgan vaqt: 5.09 min
#
# Batch 45/391 qayta ishlanmoqda, 64 ta rasm
# Batch 45 tugadi. Vaqt: 0.96s
# O'tgan vaqt: 2.23 min. Taxminiy qolgan vaqt: 5.53 min
#
# Batch 46/391 qayta ishlanmoqda, 64 ta rasm
# Batch 46 tugadi. Vaqt: 0.55s
# O'tgan vaqt: 2.24 min. Taxminiy qolgan vaqt: 3.15 min
#
# Batch 47/391 qayta ishlanmoqda, 64 ta rasm
# Batch 47 tugadi. Vaqt: 0.87s
# O'tgan vaqt: 2.26 min. Taxminiy qolgan vaqt: 5.01 min
#
# Batch 48/391 qayta ishlanmoqda, 64 ta rasm
# Batch 48 tugadi. Vaqt: 0.85s
# O'tgan vaqt: 2.28 min. Taxminiy qolgan vaqt: 4.85 min
#
# Batch 49/391 qayta ishlanmoqda, 64 ta rasm
# Batch 49 tugadi. Vaqt: 0.98s
# O'tgan vaqt: 2.31 min. Taxminiy qolgan vaqt: 5.60 min
#
# Batch 50/391 qayta ishlanmoqda, 64 ta rasm
# Batch 50 tugadi. Vaqt: 0.56s
# O'tgan vaqt: 2.32 min. Taxminiy qolgan vaqt: 3.16 min
# Xususiyatlar va yorliqlar saqlandi: features_batch_4.npy, labels_batch_4.npy
#
# Batch 51/391 qayta ishlanmoqda, 64 ta rasm
# Batch 51 tugadi. Vaqt: 0.86s
# O'tgan vaqt: 2.34 min. Taxminiy qolgan vaqt: 4.89 min
#
# Batch 52/391 qayta ishlanmoqda, 64 ta rasm
# Batch 52 tugadi. Vaqt: 0.96s
# O'tgan vaqt: 2.37 min. Taxminiy qolgan vaqt: 5.45 min
#
# Batch 53/391 qayta ishlanmoqda, 64 ta rasm
# Batch 53 tugadi. Vaqt: 0.96s
# O'tgan vaqt: 2.40 min. Taxminiy qolgan vaqt: 5.41 min
#
# Batch 54/391 qayta ishlanmoqda, 64 ta rasm
# Batch 54 tugadi. Vaqt: 0.56s
# O'tgan vaqt: 2.41 min. Taxminiy qolgan vaqt: 3.16 min
#
# Batch 55/391 qayta ishlanmoqda, 64 ta rasm
# Batch 55 tugadi. Vaqt: 0.88s
# O'tgan vaqt: 2.43 min. Taxminiy qolgan vaqt: 4.94 min
#
# Batch 56/391 qayta ishlanmoqda, 64 ta rasm
# Batch 56 tugadi. Vaqt: 0.87s
# O'tgan vaqt: 2.45 min. Taxminiy qolgan vaqt: 4.85 min
#
# Batch 57/391 qayta ishlanmoqda, 64 ta rasm
# Batch 57 tugadi. Vaqt: 0.97s
# O'tgan vaqt: 2.48 min. Taxminiy qolgan vaqt: 5.38 min
#
# Batch 58/391 qayta ishlanmoqda, 64 ta rasm
# Batch 58 tugadi. Vaqt: 0.85s
# O'tgan vaqt: 2.50 min. Taxminiy qolgan vaqt: 4.73 min
#
# Batch 59/391 qayta ishlanmoqda, 64 ta rasm
# Batch 59 tugadi. Vaqt: 0.85s
# O'tgan vaqt: 2.52 min. Taxminiy qolgan vaqt: 4.70 min
#
# Batch 60/391 qayta ishlanmoqda, 64 ta rasm
# Batch 60 tugadi. Vaqt: 0.57s
# O'tgan vaqt: 2.53 min. Taxminiy qolgan vaqt: 3.17 min
# Xususiyatlar va yorliqlar saqlandi: features_batch_5.npy, labels_batch_5.npy
#
# Batch 61/391 qayta ishlanmoqda, 64 ta rasm
# Batch 61 tugadi. Vaqt: 0.87s
# O'tgan vaqt: 2.55 min. Taxminiy qolgan vaqt: 4.77 min
#
# Batch 62/391 qayta ishlanmoqda, 64 ta rasm
# Batch 62 tugadi. Vaqt: 0.97s
# O'tgan vaqt: 2.58 min. Taxminiy qolgan vaqt: 5.33 min
#
# Batch 63/391 qayta ishlanmoqda, 64 ta rasm
# Batch 63 tugadi. Vaqt: 0.88s
# O'tgan vaqt: 2.61 min. Taxminiy qolgan vaqt: 4.83 min
#
# Batch 64/391 qayta ishlanmoqda, 64 ta rasm
# Batch 64 tugadi. Vaqt: 0.57s
# O'tgan vaqt: 2.62 min. Taxminiy qolgan vaqt: 3.11 min
#
# Batch 65/391 qayta ishlanmoqda, 64 ta rasm
# Batch 65 tugadi. Vaqt: 0.86s
# O'tgan vaqt: 2.64 min. Taxminiy qolgan vaqt: 4.70 min
#
# Batch 66/391 qayta ishlanmoqda, 64 ta rasm
# Batch 66 tugadi. Vaqt: 0.57s
# O'tgan vaqt: 2.66 min. Taxminiy qolgan vaqt: 3.10 min
#
# Batch 67/391 qayta ishlanmoqda, 64 ta rasm
# Batch 67 tugadi. Vaqt: 0.58s
# O'tgan vaqt: 2.67 min. Taxminiy qolgan vaqt: 3.15 min
#
# Batch 68/391 qayta ishlanmoqda, 64 ta rasm
# Batch 68 tugadi. Vaqt: 0.58s
# O'tgan vaqt: 2.69 min. Taxminiy qolgan vaqt: 3.11 min
#
# Batch 69/391 qayta ishlanmoqda, 64 ta rasm
# Batch 69 tugadi. Vaqt: 0.86s
# O'tgan vaqt: 2.71 min. Taxminiy qolgan vaqt: 4.59 min
#
# Batch 70/391 qayta ishlanmoqda, 64 ta rasm
# Batch 70 tugadi. Vaqt: 0.58s
# O'tgan vaqt: 2.72 min. Taxminiy qolgan vaqt: 3.08 min
# Xususiyatlar va yorliqlar saqlandi: features_batch_6.npy, labels_batch_6.npy
#
# Batch 71/391 qayta ishlanmoqda, 64 ta rasm
# Batch 71 tugadi. Vaqt: 0.88s
# O'tgan vaqt: 2.74 min. Taxminiy qolgan vaqt: 4.71 min
#
# Batch 72/391 qayta ishlanmoqda, 64 ta rasm
# Batch 72 tugadi. Vaqt: 0.88s
# O'tgan vaqt: 2.76 min. Taxminiy qolgan vaqt: 4.67 min
#
# Batch 73/391 qayta ishlanmoqda, 64 ta rasm
# Batch 73 tugadi. Vaqt: 0.96s
# O'tgan vaqt: 2.79 min. Taxminiy qolgan vaqt: 5.07 min
#
# Batch 74/391 qayta ishlanmoqda, 64 ta rasm
# Batch 74 tugadi. Vaqt: 0.68s
# O'tgan vaqt: 2.81 min. Taxminiy qolgan vaqt: 3.60 min
#
# Batch 75/391 qayta ishlanmoqda, 64 ta rasm
# Batch 75 tugadi. Vaqt: 0.57s
# O'tgan vaqt: 2.82 min. Taxminiy qolgan vaqt: 3.01 min
#
# Batch 76/391 qayta ishlanmoqda, 64 ta rasm
# Batch 76 tugadi. Vaqt: 0.87s
# O'tgan vaqt: 2.84 min. Taxminiy qolgan vaqt: 4.58 min
#
# Batch 77/391 qayta ishlanmoqda, 64 ta rasm
# Batch 77 tugadi. Vaqt: 0.87s
# O'tgan vaqt: 2.86 min. Taxminiy qolgan vaqt: 4.53 min
#
# Batch 78/391 qayta ishlanmoqda, 64 ta rasm
# Batch 78 tugadi. Vaqt: 0.59s
# O'tgan vaqt: 2.88 min. Taxminiy qolgan vaqt: 3.06 min
#
# Batch 79/391 qayta ishlanmoqda, 64 ta rasm
# Batch 79 tugadi. Vaqt: 0.58s
# O'tgan vaqt: 2.89 min. Taxminiy qolgan vaqt: 3.00 min
#
# Batch 80/391 qayta ishlanmoqda, 64 ta rasm
# Batch 80 tugadi. Vaqt: 0.58s
# O'tgan vaqt: 2.91 min. Taxminiy qolgan vaqt: 2.99 min
# Xususiyatlar va yorliqlar saqlandi: features_batch_7.npy, labels_batch_7.npy
#
# Batch 81/391 qayta ishlanmoqda, 64 ta rasm
# Batch 81 tugadi. Vaqt: 0.58s
# O'tgan vaqt: 2.92 min. Taxminiy qolgan vaqt: 3.01 min
#
# Batch 82/391 qayta ishlanmoqda, 64 ta rasm
# Batch 82 tugadi. Vaqt: 0.88s
# O'tgan vaqt: 2.94 min. Taxminiy qolgan vaqt: 4.55 min
#
# Batch 83/391 qayta ishlanmoqda, 64 ta rasm
# Batch 83 tugadi. Vaqt: 0.81s
# O'tgan vaqt: 2.97 min. Taxminiy qolgan vaqt: 4.16 min
#
# Batch 84/391 qayta ishlanmoqda, 64 ta rasm
# Batch 84 tugadi. Vaqt: 1.30s
# O'tgan vaqt: 3.02 min. Taxminiy qolgan vaqt: 6.64 min
#
# Batch 85/391 qayta ishlanmoqda, 64 ta rasm
# Batch 85 tugadi. Vaqt: 0.80s
# O'tgan vaqt: 3.04 min. Taxminiy qolgan vaqt: 4.09 min
#
# Batch 86/391 qayta ishlanmoqda, 64 ta rasm
# Batch 86 tugadi. Vaqt: 0.88s
# O'tgan vaqt: 3.07 min. Taxminiy qolgan vaqt: 4.46 min
#
# Batch 87/391 qayta ishlanmoqda, 64 ta rasm
# Batch 87 tugadi. Vaqt: 0.86s
# O'tgan vaqt: 3.09 min. Taxminiy qolgan vaqt: 4.34 min
#
# Batch 88/391 qayta ishlanmoqda, 64 ta rasm
# Batch 88 tugadi. Vaqt: 0.57s
# O'tgan vaqt: 3.10 min. Taxminiy qolgan vaqt: 2.90 min
#
# Batch 89/391 qayta ishlanmoqda, 64 ta rasm
# Batch 89 tugadi. Vaqt: 0.57s
# O'tgan vaqt: 3.12 min. Taxminiy qolgan vaqt: 2.87 min
#
# Batch 90/391 qayta ishlanmoqda, 64 ta rasm
# Batch 90 tugadi. Vaqt: 0.86s
# O'tgan vaqt: 3.14 min. Taxminiy qolgan vaqt: 4.32 min
# Xususiyatlar va yorliqlar saqlandi: features_batch_8.npy, labels_batch_8.npy
#
# Batch 91/391 qayta ishlanmoqda, 64 ta rasm
# Batch 91 tugadi. Vaqt: 0.87s
# O'tgan vaqt: 3.16 min. Taxminiy qolgan vaqt: 4.35 min
#
# Batch 92/391 qayta ishlanmoqda, 64 ta rasm
# Batch 92 tugadi. Vaqt: 0.58s
# O'tgan vaqt: 3.17 min. Taxminiy qolgan vaqt: 2.90 min
#
# Batch 93/391 qayta ishlanmoqda, 64 ta rasm
# Batch 93 tugadi. Vaqt: 0.59s
# O'tgan vaqt: 3.19 min. Taxminiy qolgan vaqt: 2.94 min
#
# Batch 94/391 qayta ishlanmoqda, 64 ta rasm
# Batch 94 tugadi. Vaqt: 0.96s
# O'tgan vaqt: 3.21 min. Taxminiy qolgan vaqt: 4.78 min
#
# Batch 95/391 qayta ishlanmoqda, 64 ta rasm
# Batch 95 tugadi. Vaqt: 0.70s
# O'tgan vaqt: 3.23 min. Taxminiy qolgan vaqt: 3.46 min
#
# Batch 96/391 qayta ishlanmoqda, 64 ta rasm
# Batch 96 tugadi. Vaqt: 0.58s
# O'tgan vaqt: 3.25 min. Taxminiy qolgan vaqt: 2.86 min
#
# Batch 97/391 qayta ishlanmoqda, 64 ta rasm
# Batch 97 tugadi. Vaqt: 0.56s
# O'tgan vaqt: 3.26 min. Taxminiy qolgan vaqt: 2.76 min
#
# Batch 98/391 qayta ishlanmoqda, 64 ta rasm
# Batch 98 tugadi. Vaqt: 0.86s
# O'tgan vaqt: 3.28 min. Taxminiy qolgan vaqt: 4.21 min
#
# Batch 99/391 qayta ishlanmoqda, 64 ta rasm
# Batch 99 tugadi. Vaqt: 0.86s
# O'tgan vaqt: 3.30 min. Taxminiy qolgan vaqt: 4.20 min
#
# Batch 100/391 qayta ishlanmoqda, 64 ta rasm
# Batch 100 tugadi. Vaqt: 0.57s
# O'tgan vaqt: 3.32 min. Taxminiy qolgan vaqt: 2.76 min
# Xususiyatlar va yorliqlar saqlandi: features_batch_9.npy, labels_batch_9.npy
#
# Batch 101/391 qayta ishlanmoqda, 64 ta rasm
# Batch 101 tugadi. Vaqt: 0.86s
# O'tgan vaqt: 3.34 min. Taxminiy qolgan vaqt: 4.17 min
#
# Batch 102/391 qayta ishlanmoqda, 64 ta rasm
# Batch 102 tugadi. Vaqt: 0.86s
# O'tgan vaqt: 3.36 min. Taxminiy qolgan vaqt: 4.16 min
#
# Batch 103/391 qayta ishlanmoqda, 64 ta rasm
# Batch 103 tugadi. Vaqt: 0.59s
# O'tgan vaqt: 3.37 min. Taxminiy qolgan vaqt: 2.82 min
#
# Batch 104/391 qayta ishlanmoqda, 64 ta rasm
# Batch 104 tugadi. Vaqt: 0.58s
# O'tgan vaqt: 3.39 min. Taxminiy qolgan vaqt: 2.76 min
#
# Batch 105/391 qayta ishlanmoqda, 64 ta rasm
# Batch 105 tugadi. Vaqt: 0.58s
# O'tgan vaqt: 3.40 min. Taxminiy qolgan vaqt: 2.77 min
#
# Batch 106/391 qayta ishlanmoqda, 64 ta rasm
# Batch 106 tugadi. Vaqt: 0.95s
# O'tgan vaqt: 3.43 min. Taxminiy qolgan vaqt: 4.53 min
#
# Batch 107/391 qayta ishlanmoqda, 64 ta rasm
# Batch 107 tugadi. Vaqt: 0.72s
# O'tgan vaqt: 3.45 min. Taxminiy qolgan vaqt: 3.42 min
#
# Batch 108/391 qayta ishlanmoqda, 64 ta rasm
# Batch 108 tugadi. Vaqt: 0.57s
# O'tgan vaqt: 3.46 min. Taxminiy qolgan vaqt: 2.69 min
#
# Batch 109/391 qayta ishlanmoqda, 64 ta rasm
# Batch 109 tugadi. Vaqt: 0.85s
# O'tgan vaqt: 3.48 min. Taxminiy qolgan vaqt: 4.00 min
#
# Batch 110/391 qayta ishlanmoqda, 64 ta rasm
# Batch 110 tugadi. Vaqt: 0.86s
# O'tgan vaqt: 3.50 min. Taxminiy qolgan vaqt: 4.03 min
# Xususiyatlar va yorliqlar saqlandi: features_batch_10.npy, labels_batch_10.npy
#
# Batch 111/391 qayta ishlanmoqda, 64 ta rasm
# Batch 111 tugadi. Vaqt: 0.85s
# O'tgan vaqt: 3.52 min. Taxminiy qolgan vaqt: 3.96 min
#
# Batch 112/391 qayta ishlanmoqda, 64 ta rasm
# Batch 112 tugadi. Vaqt: 0.87s
# O'tgan vaqt: 3.54 min. Taxminiy qolgan vaqt: 4.04 min
#
# Batch 113/391 qayta ishlanmoqda, 64 ta rasm
# Batch 113 tugadi. Vaqt: 0.86s
# O'tgan vaqt: 3.56 min. Taxminiy qolgan vaqt: 4.00 min
#
# Batch 114/391 qayta ishlanmoqda, 64 ta rasm
# Batch 114 tugadi. Vaqt: 0.58s
# O'tgan vaqt: 3.58 min. Taxminiy qolgan vaqt: 2.66 min
#
# Batch 115/391 qayta ishlanmoqda, 64 ta rasm
# Batch 115 tugadi. Vaqt: 0.58s
# O'tgan vaqt: 3.59 min. Taxminiy qolgan vaqt: 2.68 min
#
# Batch 116/391 qayta ishlanmoqda, 64 ta rasm
# Batch 116 tugadi. Vaqt: 0.57s
# O'tgan vaqt: 3.61 min. Taxminiy qolgan vaqt: 2.61 min
#
# Batch 117/391 qayta ishlanmoqda, 64 ta rasm
# Batch 117 tugadi. Vaqt: 0.97s
# O'tgan vaqt: 3.63 min. Taxminiy qolgan vaqt: 4.43 min
#
# Batch 118/391 qayta ishlanmoqda, 64 ta rasm
# Batch 118 tugadi. Vaqt: 0.97s
# O'tgan vaqt: 3.65 min. Taxminiy qolgan vaqt: 4.39 min
#
# Batch 119/391 qayta ishlanmoqda, 64 ta rasm
# Batch 119 tugadi. Vaqt: 0.86s
# O'tgan vaqt: 3.68 min. Taxminiy qolgan vaqt: 3.91 min
#
# Batch 120/391 qayta ishlanmoqda, 64 ta rasm
# Batch 120 tugadi. Vaqt: 0.57s
# O'tgan vaqt: 3.69 min. Taxminiy qolgan vaqt: 2.59 min
# Xususiyatlar va yorliqlar saqlandi: features_batch_11.npy, labels_batch_11.npy
#
# Batch 121/391 qayta ishlanmoqda, 64 ta rasm
# Batch 121 tugadi. Vaqt: 0.57s
# O'tgan vaqt: 3.71 min. Taxminiy qolgan vaqt: 2.58 min
#
# Batch 122/391 qayta ishlanmoqda, 64 ta rasm
# Batch 122 tugadi. Vaqt: 0.88s
# O'tgan vaqt: 3.73 min. Taxminiy qolgan vaqt: 3.94 min
#
# Batch 123/391 qayta ishlanmoqda, 64 ta rasm
# Batch 123 tugadi. Vaqt: 0.57s
# O'tgan vaqt: 3.74 min. Taxminiy qolgan vaqt: 2.55 min
#
# Batch 124/391 qayta ishlanmoqda, 64 ta rasm
# Batch 124 tugadi. Vaqt: 0.85s
# O'tgan vaqt: 3.76 min. Taxminiy qolgan vaqt: 3.79 min
#
# Batch 125/391 qayta ishlanmoqda, 64 ta rasm
# Batch 125 tugadi. Vaqt: 0.59s
# O'tgan vaqt: 3.78 min. Taxminiy qolgan vaqt: 2.60 min
#
# Batch 126/391 qayta ishlanmoqda, 64 ta rasm
# Batch 126 tugadi. Vaqt: 0.87s
# O'tgan vaqt: 3.80 min. Taxminiy qolgan vaqt: 3.84 min
#
# Batch 127/391 qayta ishlanmoqda, 64 ta rasm
# Batch 127 tugadi. Vaqt: 0.57s
# O'tgan vaqt: 3.81 min. Taxminiy qolgan vaqt: 2.50 min
#
# Batch 128/391 qayta ishlanmoqda, 64 ta rasm
# Batch 128 tugadi. Vaqt: 0.86s
# O'tgan vaqt: 3.83 min. Taxminiy qolgan vaqt: 3.77 min
#
# Batch 129/391 qayta ishlanmoqda, 64 ta rasm
# Batch 129 tugadi. Vaqt: 0.98s
# O'tgan vaqt: 3.86 min. Taxminiy qolgan vaqt: 4.26 min
#
# Batch 130/391 qayta ishlanmoqda, 64 ta rasm
# Batch 130 tugadi. Vaqt: 0.86s
# O'tgan vaqt: 3.88 min. Taxminiy qolgan vaqt: 3.75 min
# Xususiyatlar va yorliqlar saqlandi: features_batch_12.npy, labels_batch_12.npy
#
# Batch 131/391 qayta ishlanmoqda, 64 ta rasm
# Batch 131 tugadi. Vaqt: 0.58s
# O'tgan vaqt: 3.90 min. Taxminiy qolgan vaqt: 2.50 min
#
# Batch 132/391 qayta ishlanmoqda, 64 ta rasm
# Batch 132 tugadi. Vaqt: 0.56s
# O'tgan vaqt: 3.91 min. Taxminiy qolgan vaqt: 2.42 min
#
# Batch 133/391 qayta ishlanmoqda, 64 ta rasm
# Batch 133 tugadi. Vaqt: 0.86s
# O'tgan vaqt: 3.93 min. Taxminiy qolgan vaqt: 3.68 min
#
# Batch 134/391 qayta ishlanmoqda, 64 ta rasm
# Batch 134 tugadi. Vaqt: 0.86s
# O'tgan vaqt: 3.95 min. Taxminiy qolgan vaqt: 3.69 min
#
# Batch 135/391 qayta ishlanmoqda, 64 ta rasm
# Batch 135 tugadi. Vaqt: 0.88s
# O'tgan vaqt: 3.98 min. Taxminiy qolgan vaqt: 3.75 min
#
# Batch 136/391 qayta ishlanmoqda, 64 ta rasm
# Batch 136 tugadi. Vaqt: 0.89s
# O'tgan vaqt: 4.00 min. Taxminiy qolgan vaqt: 3.76 min
#
# Batch 137/391 qayta ishlanmoqda, 64 ta rasm
# Batch 137 tugadi. Vaqt: 0.89s
# O'tgan vaqt: 4.02 min. Taxminiy qolgan vaqt: 3.76 min
#
# Batch 138/391 qayta ishlanmoqda, 64 ta rasm
# Batch 138 tugadi. Vaqt: 0.87s
# O'tgan vaqt: 4.04 min. Taxminiy qolgan vaqt: 3.68 min
#
# Batch 139/391 qayta ishlanmoqda, 64 ta rasm
# Batch 139 tugadi. Vaqt: 0.67s
# O'tgan vaqt: 4.06 min. Taxminiy qolgan vaqt: 2.82 min
#
# Batch 140/391 qayta ishlanmoqda, 64 ta rasm
# Batch 140 tugadi. Vaqt: 0.97s
# O'tgan vaqt: 4.08 min. Taxminiy qolgan vaqt: 4.04 min
# Xususiyatlar va yorliqlar saqlandi: features_batch_13.npy, labels_batch_13.npy
#
# Batch 141/391 qayta ishlanmoqda, 64 ta rasm
# Batch 141 tugadi. Vaqt: 0.57s
# O'tgan vaqt: 4.09 min. Taxminiy qolgan vaqt: 2.38 min
#
# Batch 142/391 qayta ishlanmoqda, 64 ta rasm
# Batch 142 tugadi. Vaqt: 0.87s
# O'tgan vaqt: 4.11 min. Taxminiy qolgan vaqt: 3.60 min
#
# Batch 143/391 qayta ishlanmoqda, 64 ta rasm
# Batch 143 tugadi. Vaqt: 0.87s
# O'tgan vaqt: 4.13 min. Taxminiy qolgan vaqt: 3.58 min
#
# Batch 144/391 qayta ishlanmoqda, 64 ta rasm
# Batch 144 tugadi. Vaqt: 0.86s
# O'tgan vaqt: 4.16 min. Taxminiy qolgan vaqt: 3.53 min
#
# Batch 145/391 qayta ishlanmoqda, 64 ta rasm
# Batch 145 tugadi. Vaqt: 0.58s
# O'tgan vaqt: 4.17 min. Taxminiy qolgan vaqt: 2.39 min
#
# Batch 146/391 qayta ishlanmoqda, 64 ta rasm
# Batch 146 tugadi. Vaqt: 0.87s
# O'tgan vaqt: 4.19 min. Taxminiy qolgan vaqt: 3.55 min
#
# Batch 147/391 qayta ishlanmoqda, 64 ta rasm
# Batch 147 tugadi. Vaqt: 0.56s
# O'tgan vaqt: 4.21 min. Taxminiy qolgan vaqt: 2.26 min
#
# Batch 148/391 qayta ishlanmoqda, 64 ta rasm
# Batch 148 tugadi. Vaqt: 0.87s
# O'tgan vaqt: 4.23 min. Taxminiy qolgan vaqt: 3.53 min
#
# Batch 149/391 qayta ishlanmoqda, 64 ta rasm
# Batch 149 tugadi. Vaqt: 0.86s
# O'tgan vaqt: 4.25 min. Taxminiy qolgan vaqt: 3.47 min
#
# Batch 150/391 qayta ishlanmoqda, 64 ta rasm
# Batch 150 tugadi. Vaqt: 0.95s
# O'tgan vaqt: 4.27 min. Taxminiy qolgan vaqt: 3.81 min
# Xususiyatlar va yorliqlar saqlandi: features_batch_14.npy, labels_batch_14.npy
#
# Batch 151/391 qayta ishlanmoqda, 64 ta rasm
# Batch 151 tugadi. Vaqt: 0.98s
# O'tgan vaqt: 4.29 min. Taxminiy qolgan vaqt: 3.93 min
#
# Batch 152/391 qayta ishlanmoqda, 64 ta rasm
# Batch 152 tugadi. Vaqt: 0.85s
# O'tgan vaqt: 4.31 min. Taxminiy qolgan vaqt: 3.40 min
#
# Batch 153/391 qayta ishlanmoqda, 64 ta rasm
# Batch 153 tugadi. Vaqt: 0.86s
# O'tgan vaqt: 4.33 min. Taxminiy qolgan vaqt: 3.41 min
#
# Batch 154/391 qayta ishlanmoqda, 64 ta rasm
# Batch 154 tugadi. Vaqt: 0.56s
# O'tgan vaqt: 4.35 min. Taxminiy qolgan vaqt: 2.23 min
#
# Batch 155/391 qayta ishlanmoqda, 64 ta rasm
# Batch 155 tugadi. Vaqt: 0.86s
# O'tgan vaqt: 4.37 min. Taxminiy qolgan vaqt: 3.38 min
#
# Batch 156/391 qayta ishlanmoqda, 64 ta rasm
# Batch 156 tugadi. Vaqt: 0.87s
# O'tgan vaqt: 4.39 min. Taxminiy qolgan vaqt: 3.41 min
#
# Batch 157/391 qayta ishlanmoqda, 64 ta rasm
# Batch 157 tugadi. Vaqt: 0.57s
# O'tgan vaqt: 4.41 min. Taxminiy qolgan vaqt: 2.23 min
#
# Batch 158/391 qayta ishlanmoqda, 64 ta rasm
# Batch 158 tugadi. Vaqt: 0.86s
# O'tgan vaqt: 4.43 min. Taxminiy qolgan vaqt: 3.35 min
#
# Batch 159/391 qayta ishlanmoqda, 64 ta rasm
# Batch 159 tugadi. Vaqt: 0.58s
# O'tgan vaqt: 4.44 min. Taxminiy qolgan vaqt: 2.24 min
#
# Batch 160/391 qayta ishlanmoqda, 64 ta rasm
# Batch 160 tugadi. Vaqt: 0.59s
# O'tgan vaqt: 4.46 min. Taxminiy qolgan vaqt: 2.26 min
# Xususiyatlar va yorliqlar saqlandi: features_batch_15.npy, labels_batch_15.npy
#
# Batch 161/391 qayta ishlanmoqda, 64 ta rasm
# Batch 161 tugadi. Vaqt: 0.96s
# O'tgan vaqt: 4.48 min. Taxminiy qolgan vaqt: 3.67 min
#
# Batch 162/391 qayta ishlanmoqda, 64 ta rasm
# Batch 162 tugadi. Vaqt: 0.70s
# O'tgan vaqt: 4.50 min. Taxminiy qolgan vaqt: 2.68 min
#
# Batch 163/391 qayta ishlanmoqda, 64 ta rasm
# Batch 163 tugadi. Vaqt: 0.57s
# O'tgan vaqt: 4.52 min. Taxminiy qolgan vaqt: 2.18 min
#
# Batch 164/391 qayta ishlanmoqda, 64 ta rasm
# Batch 164 tugadi. Vaqt: 0.56s
# O'tgan vaqt: 4.53 min. Taxminiy qolgan vaqt: 2.12 min
#
# Batch 165/391 qayta ishlanmoqda, 64 ta rasm
# Batch 165 tugadi. Vaqt: 0.57s
# O'tgan vaqt: 4.55 min. Taxminiy qolgan vaqt: 2.15 min
#
# Batch 166/391 qayta ishlanmoqda, 64 ta rasm
# Batch 166 tugadi. Vaqt: 0.58s
# O'tgan vaqt: 4.56 min. Taxminiy qolgan vaqt: 2.19 min
#
# Batch 167/391 qayta ishlanmoqda, 64 ta rasm
# Batch 167 tugadi. Vaqt: 0.59s
# O'tgan vaqt: 4.58 min. Taxminiy qolgan vaqt: 2.19 min
#
# Batch 168/391 qayta ishlanmoqda, 64 ta rasm
# Batch 168 tugadi. Vaqt: 0.58s
# O'tgan vaqt: 4.59 min. Taxminiy qolgan vaqt: 2.14 min
#
# Batch 169/391 qayta ishlanmoqda, 64 ta rasm
# Batch 169 tugadi. Vaqt: 0.56s
# O'tgan vaqt: 4.61 min. Taxminiy qolgan vaqt: 2.06 min
#
# Batch 170/391 qayta ishlanmoqda, 64 ta rasm
# Batch 170 tugadi. Vaqt: 0.86s
# O'tgan vaqt: 4.63 min. Taxminiy qolgan vaqt: 3.15 min
# Xususiyatlar va yorliqlar saqlandi: features_batch_16.npy, labels_batch_16.npy
#
# Batch 171/391 qayta ishlanmoqda, 64 ta rasm
# Batch 171 tugadi. Vaqt: 0.87s
# O'tgan vaqt: 4.65 min. Taxminiy qolgan vaqt: 3.20 min
#
# Batch 172/391 qayta ishlanmoqda, 64 ta rasm
# Batch 172 tugadi. Vaqt: 0.57s
# O'tgan vaqt: 4.66 min. Taxminiy qolgan vaqt: 2.09 min
#
# Batch 173/391 qayta ishlanmoqda, 64 ta rasm
# Batch 173 tugadi. Vaqt: 0.96s
# O'tgan vaqt: 4.69 min. Taxminiy qolgan vaqt: 3.48 min
#
# Batch 174/391 qayta ishlanmoqda, 64 ta rasm
# Batch 174 tugadi. Vaqt: 0.98s
# O'tgan vaqt: 4.71 min. Taxminiy qolgan vaqt: 3.56 min
#
# Batch 175/391 qayta ishlanmoqda, 64 ta rasm
# Batch 175 tugadi. Vaqt: 0.57s
# O'tgan vaqt: 4.72 min. Taxminiy qolgan vaqt: 2.03 min
#
# Batch 176/391 qayta ishlanmoqda, 64 ta rasm
# Batch 176 tugadi. Vaqt: 0.86s
# O'tgan vaqt: 4.74 min. Taxminiy qolgan vaqt: 3.07 min
#
# Batch 177/391 qayta ishlanmoqda, 64 ta rasm
# Batch 177 tugadi. Vaqt: 0.56s
# O'tgan vaqt: 4.76 min. Taxminiy qolgan vaqt: 2.01 min
#
# Batch 178/391 qayta ishlanmoqda, 64 ta rasm
# Batch 178 tugadi. Vaqt: 0.87s
# O'tgan vaqt: 4.78 min. Taxminiy qolgan vaqt: 3.08 min
#
# Batch 179/391 qayta ishlanmoqda, 64 ta rasm
# Batch 179 tugadi. Vaqt: 0.86s
# O'tgan vaqt: 4.80 min. Taxminiy qolgan vaqt: 3.03 min
#
# Batch 180/391 qayta ishlanmoqda, 64 ta rasm
# Batch 180 tugadi. Vaqt: 0.59s
# O'tgan vaqt: 4.82 min. Taxminiy qolgan vaqt: 2.09 min
# Xususiyatlar va yorliqlar saqlandi: features_batch_17.npy, labels_batch_17.npy
#
# Batch 181/391 qayta ishlanmoqda, 64 ta rasm
# Batch 181 tugadi. Vaqt: 0.88s
# O'tgan vaqt: 4.84 min. Taxminiy qolgan vaqt: 3.07 min
#
# Batch 182/391 qayta ishlanmoqda, 64 ta rasm
# Batch 182 tugadi. Vaqt: 0.58s
# O'tgan vaqt: 4.85 min. Taxminiy qolgan vaqt: 2.03 min
#
# Batch 183/391 qayta ishlanmoqda, 64 ta rasm
# Batch 183 tugadi. Vaqt: 0.87s
# O'tgan vaqt: 4.87 min. Taxminiy qolgan vaqt: 3.03 min
#
# Batch 184/391 qayta ishlanmoqda, 64 ta rasm
# Batch 184 tugadi. Vaqt: 0.69s
# O'tgan vaqt: 4.89 min. Taxminiy qolgan vaqt: 2.38 min
#
# Batch 185/391 qayta ishlanmoqda, 64 ta rasm
# Batch 185 tugadi. Vaqt: 0.96s
# O'tgan vaqt: 4.91 min. Taxminiy qolgan vaqt: 3.29 min
#
# Batch 186/391 qayta ishlanmoqda, 64 ta rasm
# Batch 186 tugadi. Vaqt: 0.86s
# O'tgan vaqt: 4.94 min. Taxminiy qolgan vaqt: 2.95 min
#
# Batch 187/391 qayta ishlanmoqda, 64 ta rasm
# Batch 187 tugadi. Vaqt: 0.87s
# O'tgan vaqt: 4.96 min. Taxminiy qolgan vaqt: 2.94 min
#
# Batch 188/391 qayta ishlanmoqda, 64 ta rasm
# Batch 188 tugadi. Vaqt: 0.89s
# O'tgan vaqt: 4.98 min. Taxminiy qolgan vaqt: 3.00 min
#
# Batch 189/391 qayta ishlanmoqda, 64 ta rasm
# Batch 189 tugadi. Vaqt: 0.87s
# O'tgan vaqt: 5.00 min. Taxminiy qolgan vaqt: 2.93 min
#
# Batch 190/391 qayta ishlanmoqda, 64 ta rasm
# Batch 190 tugadi. Vaqt: 0.56s
# O'tgan vaqt: 5.01 min. Taxminiy qolgan vaqt: 1.88 min
# Xususiyatlar va yorliqlar saqlandi: features_batch_18.npy, labels_batch_18.npy
#
# Batch 191/391 qayta ishlanmoqda, 64 ta rasm
# Batch 191 tugadi. Vaqt: 0.56s
# O'tgan vaqt: 5.03 min. Taxminiy qolgan vaqt: 1.87 min
#
# Batch 192/391 qayta ishlanmoqda, 64 ta rasm
# Batch 192 tugadi. Vaqt: 0.87s
# O'tgan vaqt: 5.05 min. Taxminiy qolgan vaqt: 2.87 min
#
# Batch 193/391 qayta ishlanmoqda, 64 ta rasm
# Batch 193 tugadi. Vaqt: 0.86s
# O'tgan vaqt: 5.07 min. Taxminiy qolgan vaqt: 2.83 min
#
# Batch 194/391 qayta ishlanmoqda, 64 ta rasm
# Batch 194 tugadi. Vaqt: 0.56s
# O'tgan vaqt: 5.08 min. Taxminiy qolgan vaqt: 1.85 min
#
# Batch 195/391 qayta ishlanmoqda, 64 ta rasm
# Batch 195 tugadi. Vaqt: 0.96s
# O'tgan vaqt: 5.10 min. Taxminiy qolgan vaqt: 3.15 min
#
# Batch 196/391 qayta ishlanmoqda, 64 ta rasm
# Batch 196 tugadi. Vaqt: 0.97s
# O'tgan vaqt: 5.13 min. Taxminiy qolgan vaqt: 3.14 min
#
# Batch 197/391 qayta ishlanmoqda, 64 ta rasm
# Batch 197 tugadi. Vaqt: 0.58s
# O'tgan vaqt: 5.14 min. Taxminiy qolgan vaqt: 1.87 min
#
# Batch 198/391 qayta ishlanmoqda, 64 ta rasm
# Batch 198 tugadi. Vaqt: 0.58s
# O'tgan vaqt: 5.16 min. Taxminiy qolgan vaqt: 1.86 min
#
# Batch 199/391 qayta ishlanmoqda, 64 ta rasm
# Batch 199 tugadi. Vaqt: 0.87s
# O'tgan vaqt: 5.18 min. Taxminiy qolgan vaqt: 2.79 min
#
# Batch 200/391 qayta ishlanmoqda, 64 ta rasm
# Batch 200 tugadi. Vaqt: 0.86s
# O'tgan vaqt: 5.20 min. Taxminiy qolgan vaqt: 2.74 min
# Xususiyatlar va yorliqlar saqlandi: features_batch_19.npy, labels_batch_19.npy
#
# Batch 201/391 qayta ishlanmoqda, 64 ta rasm
# Batch 201 tugadi. Vaqt: 0.56s
# O'tgan vaqt: 5.22 min. Taxminiy qolgan vaqt: 1.78 min
#
# Batch 202/391 qayta ishlanmoqda, 64 ta rasm
# Batch 202 tugadi. Vaqt: 0.86s
# O'tgan vaqt: 5.24 min. Taxminiy qolgan vaqt: 2.70 min
#
# Batch 203/391 qayta ishlanmoqda, 64 ta rasm
# Batch 203 tugadi. Vaqt: 0.56s
# O'tgan vaqt: 5.25 min. Taxminiy qolgan vaqt: 1.76 min
#
# Batch 204/391 qayta ishlanmoqda, 64 ta rasm
# Batch 204 tugadi. Vaqt: 0.85s
# O'tgan vaqt: 5.27 min. Taxminiy qolgan vaqt: 2.66 min
#
# Batch 205/391 qayta ishlanmoqda, 64 ta rasm
# Batch 205 tugadi. Vaqt: 0.58s
# O'tgan vaqt: 5.29 min. Taxminiy qolgan vaqt: 1.81 min
#
# Batch 206/391 qayta ishlanmoqda, 64 ta rasm
# Batch 206 tugadi. Vaqt: 0.86s
# O'tgan vaqt: 5.31 min. Taxminiy qolgan vaqt: 2.67 min
#
# Batch 207/391 qayta ishlanmoqda, 64 ta rasm
# Batch 207 tugadi. Vaqt: 0.95s
# O'tgan vaqt: 5.33 min. Taxminiy qolgan vaqt: 2.93 min
#
# Batch 208/391 qayta ishlanmoqda, 64 ta rasm
# Batch 208 tugadi. Vaqt: 0.61s
# O'tgan vaqt: 5.35 min. Taxminiy qolgan vaqt: 1.87 min
#
# Batch 209/391 qayta ishlanmoqda, 64 ta rasm
# Batch 209 tugadi. Vaqt: 0.57s
# O'tgan vaqt: 5.36 min. Taxminiy qolgan vaqt: 1.73 min
#
# Batch 210/391 qayta ishlanmoqda, 64 ta rasm
# Batch 210 tugadi. Vaqt: 0.87s
# O'tgan vaqt: 5.38 min. Taxminiy qolgan vaqt: 2.62 min
# Xususiyatlar va yorliqlar saqlandi: features_batch_20.npy, labels_batch_20.npy
#
# Batch 211/391 qayta ishlanmoqda, 64 ta rasm
# Batch 211 tugadi. Vaqt: 0.85s
# O'tgan vaqt: 5.40 min. Taxminiy qolgan vaqt: 2.56 min
#
# Batch 212/391 qayta ishlanmoqda, 64 ta rasm
# Batch 212 tugadi. Vaqt: 0.57s
# O'tgan vaqt: 5.42 min. Taxminiy qolgan vaqt: 1.70 min
#
# Batch 213/391 qayta ishlanmoqda, 64 ta rasm
# Batch 213 tugadi. Vaqt: 0.57s
# O'tgan vaqt: 5.43 min. Taxminiy qolgan vaqt: 1.70 min
#
# Batch 214/391 qayta ishlanmoqda, 64 ta rasm
# Batch 214 tugadi. Vaqt: 0.57s
# O'tgan vaqt: 5.45 min. Taxminiy qolgan vaqt: 1.69 min
#
# Batch 215/391 qayta ishlanmoqda, 64 ta rasm
# Batch 215 tugadi. Vaqt: 0.86s
# O'tgan vaqt: 5.47 min. Taxminiy qolgan vaqt: 2.52 min
#
# Batch 216/391 qayta ishlanmoqda, 64 ta rasm
# Batch 216 tugadi. Vaqt: 0.57s
# O'tgan vaqt: 5.48 min. Taxminiy qolgan vaqt: 1.66 min
#
# Batch 217/391 qayta ishlanmoqda, 64 ta rasm
# Batch 217 tugadi. Vaqt: 0.58s
# O'tgan vaqt: 5.50 min. Taxminiy qolgan vaqt: 1.68 min
#
# Batch 218/391 qayta ishlanmoqda, 64 ta rasm
# Batch 218 tugadi. Vaqt: 0.93s
# O'tgan vaqt: 5.52 min. Taxminiy qolgan vaqt: 2.68 min
#
# Batch 219/391 qayta ishlanmoqda, 64 ta rasm
# Batch 219 tugadi. Vaqt: 0.96s
# O'tgan vaqt: 5.54 min. Taxminiy qolgan vaqt: 2.76 min
#
# Batch 220/391 qayta ishlanmoqda, 64 ta rasm
# Batch 220 tugadi. Vaqt: 0.58s
# O'tgan vaqt: 5.56 min. Taxminiy qolgan vaqt: 1.64 min
# Xususiyatlar va yorliqlar saqlandi: features_batch_21.npy, labels_batch_21.npy
#
# Batch 221/391 qayta ishlanmoqda, 64 ta rasm
# Batch 221 tugadi. Vaqt: 0.56s
# O'tgan vaqt: 5.58 min. Taxminiy qolgan vaqt: 1.59 min
#
# Batch 222/391 qayta ishlanmoqda, 64 ta rasm
# Batch 222 tugadi. Vaqt: 0.56s
# O'tgan vaqt: 5.59 min. Taxminiy qolgan vaqt: 1.59 min
#
# Batch 223/391 qayta ishlanmoqda, 64 ta rasm
# Batch 223 tugadi. Vaqt: 0.57s
# O'tgan vaqt: 5.61 min. Taxminiy qolgan vaqt: 1.61 min
#
# Batch 224/391 qayta ishlanmoqda, 64 ta rasm
# Batch 224 tugadi. Vaqt: 0.58s
# O'tgan vaqt: 5.62 min. Taxminiy qolgan vaqt: 1.61 min
#
# Batch 225/391 qayta ishlanmoqda, 64 ta rasm
# Batch 225 tugadi. Vaqt: 0.56s
# O'tgan vaqt: 5.64 min. Taxminiy qolgan vaqt: 1.54 min
#
# Batch 226/391 qayta ishlanmoqda, 64 ta rasm
# Batch 226 tugadi. Vaqt: 0.85s
# O'tgan vaqt: 5.66 min. Taxminiy qolgan vaqt: 2.35 min
#
# Batch 227/391 qayta ishlanmoqda, 64 ta rasm
# Batch 227 tugadi. Vaqt: 0.87s
# O'tgan vaqt: 5.68 min. Taxminiy qolgan vaqt: 2.39 min
#
# Batch 228/391 qayta ishlanmoqda, 64 ta rasm
# Batch 228 tugadi. Vaqt: 0.86s
# O'tgan vaqt: 5.70 min. Taxminiy qolgan vaqt: 2.34 min
#
# Batch 229/391 qayta ishlanmoqda, 64 ta rasm
# Batch 229 tugadi. Vaqt: 0.57s
# O'tgan vaqt: 5.71 min. Taxminiy qolgan vaqt: 1.53 min
#
# Batch 230/391 qayta ishlanmoqda, 64 ta rasm
# Batch 230 tugadi. Vaqt: 0.98s
# O'tgan vaqt: 5.73 min. Taxminiy qolgan vaqt: 2.64 min
# Xususiyatlar va yorliqlar saqlandi: features_batch_22.npy, labels_batch_22.npy
#
# Batch 231/391 qayta ishlanmoqda, 64 ta rasm
# Batch 231 tugadi. Vaqt: 0.96s
# O'tgan vaqt: 5.76 min. Taxminiy qolgan vaqt: 2.57 min
#
# Batch 232/391 qayta ishlanmoqda, 64 ta rasm
# Batch 232 tugadi. Vaqt: 0.87s
# O'tgan vaqt: 5.78 min. Taxminiy qolgan vaqt: 2.30 min
#
# Batch 233/391 qayta ishlanmoqda, 64 ta rasm
# Batch 233 tugadi. Vaqt: 0.57s
# O'tgan vaqt: 5.79 min. Taxminiy qolgan vaqt: 1.49 min
#
# Batch 234/391 qayta ishlanmoqda, 64 ta rasm
# Batch 234 tugadi. Vaqt: 0.86s
# O'tgan vaqt: 5.81 min. Taxminiy qolgan vaqt: 2.25 min
#
# Batch 235/391 qayta ishlanmoqda, 64 ta rasm
# Batch 235 tugadi. Vaqt: 0.56s
# O'tgan vaqt: 5.83 min. Taxminiy qolgan vaqt: 1.46 min
#
# Batch 236/391 qayta ishlanmoqda, 64 ta rasm
# Batch 236 tugadi. Vaqt: 0.86s
# O'tgan vaqt: 5.85 min. Taxminiy qolgan vaqt: 2.21 min
#
# Batch 237/391 qayta ishlanmoqda, 64 ta rasm
# Batch 237 tugadi. Vaqt: 0.56s
# O'tgan vaqt: 5.86 min. Taxminiy qolgan vaqt: 1.44 min
#
# Batch 238/391 qayta ishlanmoqda, 64 ta rasm
# Batch 238 tugadi. Vaqt: 0.86s
# O'tgan vaqt: 5.88 min. Taxminiy qolgan vaqt: 2.18 min
#
# Batch 239/391 qayta ishlanmoqda, 64 ta rasm
# Batch 239 tugadi. Vaqt: 0.87s
# O'tgan vaqt: 5.90 min. Taxminiy qolgan vaqt: 2.21 min
#
# Batch 240/391 qayta ishlanmoqda, 64 ta rasm
# Batch 240 tugadi. Vaqt: 0.58s
# O'tgan vaqt: 5.92 min. Taxminiy qolgan vaqt: 1.46 min
# Xususiyatlar va yorliqlar saqlandi: features_batch_23.npy, labels_batch_23.npy
#
# Batch 241/391 qayta ishlanmoqda, 64 ta rasm
# Batch 241 tugadi. Vaqt: 0.94s
# O'tgan vaqt: 5.94 min. Taxminiy qolgan vaqt: 2.35 min
#
# Batch 242/391 qayta ishlanmoqda, 64 ta rasm
# Batch 242 tugadi. Vaqt: 0.96s
# O'tgan vaqt: 5.96 min. Taxminiy qolgan vaqt: 2.39 min
#
# Batch 243/391 qayta ishlanmoqda, 64 ta rasm
# Batch 243 tugadi. Vaqt: 0.85s
# O'tgan vaqt: 5.99 min. Taxminiy qolgan vaqt: 2.10 min
#
# Batch 244/391 qayta ishlanmoqda, 64 ta rasm
# Batch 244 tugadi. Vaqt: 0.56s
# O'tgan vaqt: 6.00 min. Taxminiy qolgan vaqt: 1.37 min
#
# Batch 245/391 qayta ishlanmoqda, 64 ta rasm
# Batch 245 tugadi. Vaqt: 0.85s
# O'tgan vaqt: 6.02 min. Taxminiy qolgan vaqt: 2.07 min
#
# Batch 246/391 qayta ishlanmoqda, 64 ta rasm
# Batch 246 tugadi. Vaqt: 0.57s
# O'tgan vaqt: 6.04 min. Taxminiy qolgan vaqt: 1.37 min
#
# Batch 247/391 qayta ishlanmoqda, 64 ta rasm
# Batch 247 tugadi. Vaqt: 0.85s
# O'tgan vaqt: 6.06 min. Taxminiy qolgan vaqt: 2.05 min
#
# Batch 248/391 qayta ishlanmoqda, 64 ta rasm
# Batch 248 tugadi. Vaqt: 0.59s
# O'tgan vaqt: 6.07 min. Taxminiy qolgan vaqt: 1.42 min
#
# Batch 249/391 qayta ishlanmoqda, 64 ta rasm
# Batch 249 tugadi. Vaqt: 0.58s
# O'tgan vaqt: 6.09 min. Taxminiy qolgan vaqt: 1.36 min
#
# Batch 250/391 qayta ishlanmoqda, 64 ta rasm
# Batch 250 tugadi. Vaqt: 0.85s
# O'tgan vaqt: 6.11 min. Taxminiy qolgan vaqt: 2.00 min
# Xususiyatlar va yorliqlar saqlandi: features_batch_24.npy, labels_batch_24.npy
#
# Batch 251/391 qayta ishlanmoqda, 64 ta rasm
# Batch 251 tugadi. Vaqt: 0.88s
# O'tgan vaqt: 6.13 min. Taxminiy qolgan vaqt: 2.04 min
#
# Batch 252/391 qayta ishlanmoqda, 64 ta rasm
# Batch 252 tugadi. Vaqt: 0.86s
# O'tgan vaqt: 6.15 min. Taxminiy qolgan vaqt: 1.99 min
#
# Batch 253/391 qayta ishlanmoqda, 64 ta rasm
# Batch 253 tugadi. Vaqt: 0.96s
# O'tgan vaqt: 6.17 min. Taxminiy qolgan vaqt: 2.21 min
#
# Batch 254/391 qayta ishlanmoqda, 64 ta rasm
# Batch 254 tugadi. Vaqt: 0.86s
# O'tgan vaqt: 6.19 min. Taxminiy qolgan vaqt: 1.96 min
#
# Batch 255/391 qayta ishlanmoqda, 64 ta rasm
# Batch 255 tugadi. Vaqt: 0.87s
# O'tgan vaqt: 6.21 min. Taxminiy qolgan vaqt: 1.98 min
#
# Batch 256/391 qayta ishlanmoqda, 64 ta rasm
# Batch 256 tugadi. Vaqt: 0.85s
# O'tgan vaqt: 6.23 min. Taxminiy qolgan vaqt: 1.92 min
#
# Batch 257/391 qayta ishlanmoqda, 64 ta rasm
# Batch 257 tugadi. Vaqt: 0.55s
# O'tgan vaqt: 6.25 min. Taxminiy qolgan vaqt: 1.24 min
#
# Batch 258/391 qayta ishlanmoqda, 64 ta rasm
# Batch 258 tugadi. Vaqt: 0.55s
# O'tgan vaqt: 6.26 min. Taxminiy qolgan vaqt: 1.23 min
#
# Batch 259/391 qayta ishlanmoqda, 64 ta rasm
# Batch 259 tugadi. Vaqt: 0.86s
# O'tgan vaqt: 6.28 min. Taxminiy qolgan vaqt: 1.89 min
#
# Batch 260/391 qayta ishlanmoqda, 64 ta rasm
# Batch 260 tugadi. Vaqt: 0.85s
# O'tgan vaqt: 6.30 min. Taxminiy qolgan vaqt: 1.86 min
# Xususiyatlar va yorliqlar saqlandi: features_batch_25.npy, labels_batch_25.npy
#
# Batch 261/391 qayta ishlanmoqda, 64 ta rasm
# Batch 261 tugadi. Vaqt: 0.87s
# O'tgan vaqt: 6.32 min. Taxminiy qolgan vaqt: 1.88 min
#
# Batch 262/391 qayta ishlanmoqda, 64 ta rasm
# Batch 262 tugadi. Vaqt: 0.57s
# O'tgan vaqt: 6.34 min. Taxminiy qolgan vaqt: 1.24 min
#
# Batch 263/391 qayta ishlanmoqda, 64 ta rasm
# Batch 263 tugadi. Vaqt: 0.95s
# O'tgan vaqt: 6.36 min. Taxminiy qolgan vaqt: 2.03 min
#
# Batch 264/391 qayta ishlanmoqda, 64 ta rasm
# Batch 264 tugadi. Vaqt: 0.98s
# O'tgan vaqt: 6.38 min. Taxminiy qolgan vaqt: 2.07 min
#
# Batch 265/391 qayta ishlanmoqda, 64 ta rasm
# Batch 265 tugadi. Vaqt: 0.86s
# O'tgan vaqt: 6.41 min. Taxminiy qolgan vaqt: 1.81 min
#
# Batch 266/391 qayta ishlanmoqda, 64 ta rasm
# Batch 266 tugadi. Vaqt: 0.58s
# O'tgan vaqt: 6.42 min. Taxminiy qolgan vaqt: 1.20 min
#
# Batch 267/391 qayta ishlanmoqda, 64 ta rasm
# Batch 267 tugadi. Vaqt: 0.86s
# O'tgan vaqt: 6.44 min. Taxminiy qolgan vaqt: 1.77 min
#
# Batch 268/391 qayta ishlanmoqda, 64 ta rasm
# Batch 268 tugadi. Vaqt: 0.86s
# O'tgan vaqt: 6.46 min. Taxminiy qolgan vaqt: 1.76 min
#
# Batch 269/391 qayta ishlanmoqda, 64 ta rasm
# Batch 269 tugadi. Vaqt: 0.85s
# O'tgan vaqt: 6.48 min. Taxminiy qolgan vaqt: 1.74 min
#
# Batch 270/391 qayta ishlanmoqda, 64 ta rasm
# Batch 270 tugadi. Vaqt: 0.56s
# O'tgan vaqt: 6.50 min. Taxminiy qolgan vaqt: 1.13 min
# Xususiyatlar va yorliqlar saqlandi: features_batch_26.npy, labels_batch_26.npy
#
# Batch 271/391 qayta ishlanmoqda, 64 ta rasm
# Batch 271 tugadi. Vaqt: 0.86s
# O'tgan vaqt: 6.52 min. Taxminiy qolgan vaqt: 1.72 min
#
# Batch 272/391 qayta ishlanmoqda, 64 ta rasm
# Batch 272 tugadi. Vaqt: 0.86s
# O'tgan vaqt: 6.54 min. Taxminiy qolgan vaqt: 1.70 min
#
# Batch 273/391 qayta ishlanmoqda, 64 ta rasm
# Batch 273 tugadi. Vaqt: 0.57s
# O'tgan vaqt: 6.55 min. Taxminiy qolgan vaqt: 1.13 min
#
# Batch 274/391 qayta ishlanmoqda, 64 ta rasm
# Batch 274 tugadi. Vaqt: 0.98s
# O'tgan vaqt: 6.57 min. Taxminiy qolgan vaqt: 1.90 min
#
# Batch 275/391 qayta ishlanmoqda, 64 ta rasm
# Batch 275 tugadi. Vaqt: 0.95s
# O'tgan vaqt: 6.60 min. Taxminiy qolgan vaqt: 1.84 min
#
# Batch 276/391 qayta ishlanmoqda, 64 ta rasm
# Batch 276 tugadi. Vaqt: 0.56s
# O'tgan vaqt: 6.61 min. Taxminiy qolgan vaqt: 1.07 min
#
# Batch 277/391 qayta ishlanmoqda, 64 ta rasm
# Batch 277 tugadi. Vaqt: 0.56s
# O'tgan vaqt: 6.63 min. Taxminiy qolgan vaqt: 1.06 min
#
# Batch 278/391 qayta ishlanmoqda, 64 ta rasm
# Batch 278 tugadi. Vaqt: 0.85s
# O'tgan vaqt: 6.65 min. Taxminiy qolgan vaqt: 1.61 min
#
# Batch 279/391 qayta ishlanmoqda, 64 ta rasm
# Batch 279 tugadi. Vaqt: 0.56s
# O'tgan vaqt: 6.66 min. Taxminiy qolgan vaqt: 1.05 min
#
# Batch 280/391 qayta ishlanmoqda, 64 ta rasm
# Batch 280 tugadi. Vaqt: 0.56s
# O'tgan vaqt: 6.68 min. Taxminiy qolgan vaqt: 1.04 min
# Xususiyatlar va yorliqlar saqlandi: features_batch_27.npy, labels_batch_27.npy
#
# Batch 281/391 qayta ishlanmoqda, 64 ta rasm
# Batch 281 tugadi. Vaqt: 0.56s
# O'tgan vaqt: 6.69 min. Taxminiy qolgan vaqt: 1.03 min
#
# Batch 282/391 qayta ishlanmoqda, 64 ta rasm
# Batch 282 tugadi. Vaqt: 0.57s
# O'tgan vaqt: 6.71 min. Taxminiy qolgan vaqt: 1.03 min
#
# Batch 283/391 qayta ishlanmoqda, 64 ta rasm
# Batch 283 tugadi. Vaqt: 0.59s
# O'tgan vaqt: 6.72 min. Taxminiy qolgan vaqt: 1.06 min
#
# Batch 284/391 qayta ishlanmoqda, 64 ta rasm
# Batch 284 tugadi. Vaqt: 0.58s
# O'tgan vaqt: 6.74 min. Taxminiy qolgan vaqt: 1.04 min
#
# Batch 285/391 qayta ishlanmoqda, 64 ta rasm
# Batch 285 tugadi. Vaqt: 0.60s
# O'tgan vaqt: 6.76 min. Taxminiy qolgan vaqt: 1.05 min
#
# Batch 286/391 qayta ishlanmoqda, 64 ta rasm
# Batch 286 tugadi. Vaqt: 0.88s
# O'tgan vaqt: 6.78 min. Taxminiy qolgan vaqt: 1.53 min
#
# Batch 287/391 qayta ishlanmoqda, 64 ta rasm
# Batch 287 tugadi. Vaqt: 0.69s
# O'tgan vaqt: 6.79 min. Taxminiy qolgan vaqt: 1.19 min
#
# Batch 288/391 qayta ishlanmoqda, 64 ta rasm
# Batch 288 tugadi. Vaqt: 0.98s
# O'tgan vaqt: 6.82 min. Taxminiy qolgan vaqt: 1.67 min
#
# Batch 289/391 qayta ishlanmoqda, 64 ta rasm
# Batch 289 tugadi. Vaqt: 0.86s
# O'tgan vaqt: 6.84 min. Taxminiy qolgan vaqt: 1.45 min
#
# Batch 290/391 qayta ishlanmoqda, 64 ta rasm
# Batch 290 tugadi. Vaqt: 0.87s
# O'tgan vaqt: 6.86 min. Taxminiy qolgan vaqt: 1.46 min
# Xususiyatlar va yorliqlar saqlandi: features_batch_28.npy, labels_batch_28.npy
#
# Batch 291/391 qayta ishlanmoqda, 64 ta rasm
# Batch 291 tugadi. Vaqt: 0.56s
# O'tgan vaqt: 6.87 min. Taxminiy qolgan vaqt: 0.94 min
#
# Batch 292/391 qayta ishlanmoqda, 64 ta rasm
# Batch 292 tugadi. Vaqt: 0.86s
# O'tgan vaqt: 6.89 min. Taxminiy qolgan vaqt: 1.42 min
#
# Batch 293/391 qayta ishlanmoqda, 64 ta rasm
# Batch 293 tugadi. Vaqt: 0.57s
# O'tgan vaqt: 6.91 min. Taxminiy qolgan vaqt: 0.93 min
#
# Batch 294/391 qayta ishlanmoqda, 64 ta rasm
# Batch 294 tugadi. Vaqt: 0.86s
# O'tgan vaqt: 6.93 min. Taxminiy qolgan vaqt: 1.39 min
#
# Batch 295/391 qayta ishlanmoqda, 64 ta rasm
# Batch 295 tugadi. Vaqt: 0.86s
# O'tgan vaqt: 6.95 min. Taxminiy qolgan vaqt: 1.37 min
#
# Batch 296/391 qayta ishlanmoqda, 64 ta rasm
# Batch 296 tugadi. Vaqt: 0.57s
# O'tgan vaqt: 6.96 min. Taxminiy qolgan vaqt: 0.90 min
#
# Batch 297/391 qayta ishlanmoqda, 64 ta rasm
# Batch 297 tugadi. Vaqt: 0.57s
# O'tgan vaqt: 6.98 min. Taxminiy qolgan vaqt: 0.90 min
#
# Batch 298/391 qayta ishlanmoqda, 64 ta rasm
# Batch 298 tugadi. Vaqt: 0.96s
# O'tgan vaqt: 7.00 min. Taxminiy qolgan vaqt: 1.48 min
#
# Batch 299/391 qayta ishlanmoqda, 64 ta rasm
# Batch 299 tugadi. Vaqt: 0.99s
# O'tgan vaqt: 7.03 min. Taxminiy qolgan vaqt: 1.51 min
#
# Batch 300/391 qayta ishlanmoqda, 64 ta rasm
# Batch 300 tugadi. Vaqt: 0.85s
# O'tgan vaqt: 7.05 min. Taxminiy qolgan vaqt: 1.29 min
# Xususiyatlar va yorliqlar saqlandi: features_batch_29.npy, labels_batch_29.npy
#
# Batch 301/391 qayta ishlanmoqda, 64 ta rasm
# Batch 301 tugadi. Vaqt: 0.56s
# O'tgan vaqt: 7.06 min. Taxminiy qolgan vaqt: 0.84 min
#
# Batch 302/391 qayta ishlanmoqda, 64 ta rasm
# Batch 302 tugadi. Vaqt: 0.85s
# O'tgan vaqt: 7.08 min. Taxminiy qolgan vaqt: 1.26 min
#
# Batch 303/391 qayta ishlanmoqda, 64 ta rasm
# Batch 303 tugadi. Vaqt: 0.56s
# O'tgan vaqt: 7.10 min. Taxminiy qolgan vaqt: 0.82 min
#
# Batch 304/391 qayta ishlanmoqda, 64 ta rasm
# Batch 304 tugadi. Vaqt: 0.85s
# O'tgan vaqt: 7.12 min. Taxminiy qolgan vaqt: 1.24 min
#
# Batch 305/391 qayta ishlanmoqda, 64 ta rasm
# Batch 305 tugadi. Vaqt: 0.86s
# O'tgan vaqt: 7.14 min. Taxminiy qolgan vaqt: 1.23 min
#
# Batch 306/391 qayta ishlanmoqda, 64 ta rasm
# Batch 306 tugadi. Vaqt: 0.87s
# O'tgan vaqt: 7.16 min. Taxminiy qolgan vaqt: 1.23 min
#
# Batch 307/391 qayta ishlanmoqda, 64 ta rasm
# Batch 307 tugadi. Vaqt: 0.87s
# O'tgan vaqt: 7.18 min. Taxminiy qolgan vaqt: 1.21 min
#
# Batch 308/391 qayta ishlanmoqda, 64 ta rasm
# Batch 308 tugadi. Vaqt: 0.57s
# O'tgan vaqt: 7.19 min. Taxminiy qolgan vaqt: 0.79 min
#
# Batch 309/391 qayta ishlanmoqda, 64 ta rasm
# Batch 309 tugadi. Vaqt: 0.96s
# O'tgan vaqt: 7.22 min. Taxminiy qolgan vaqt: 1.31 min
#
# Batch 310/391 qayta ishlanmoqda, 64 ta rasm
# Batch 310 tugadi. Vaqt: 0.99s
# O'tgan vaqt: 7.24 min. Taxminiy qolgan vaqt: 1.34 min
# Xususiyatlar va yorliqlar saqlandi: features_batch_30.npy, labels_batch_30.npy
#
# Batch 311/391 qayta ishlanmoqda, 64 ta rasm
# Batch 311 tugadi. Vaqt: 0.58s
# O'tgan vaqt: 7.26 min. Taxminiy qolgan vaqt: 0.77 min
#
# Batch 312/391 qayta ishlanmoqda, 64 ta rasm
# Batch 312 tugadi. Vaqt: 0.57s
# O'tgan vaqt: 7.27 min. Taxminiy qolgan vaqt: 0.75 min
#
# Batch 313/391 qayta ishlanmoqda, 64 ta rasm
# Batch 313 tugadi. Vaqt: 0.86s
# O'tgan vaqt: 7.29 min. Taxminiy qolgan vaqt: 1.12 min
#
# Batch 314/391 qayta ishlanmoqda, 64 ta rasm
# Batch 314 tugadi. Vaqt: 0.87s
# O'tgan vaqt: 7.31 min. Taxminiy qolgan vaqt: 1.11 min
#
# Batch 315/391 qayta ishlanmoqda, 64 ta rasm
# Batch 315 tugadi. Vaqt: 0.56s
# O'tgan vaqt: 7.33 min. Taxminiy qolgan vaqt: 0.70 min
#
# Batch 316/391 qayta ishlanmoqda, 64 ta rasm
# Batch 316 tugadi. Vaqt: 0.86s
# O'tgan vaqt: 7.35 min. Taxminiy qolgan vaqt: 1.07 min
#
# Batch 317/391 qayta ishlanmoqda, 64 ta rasm
# Batch 317 tugadi. Vaqt: 0.86s
# O'tgan vaqt: 7.37 min. Taxminiy qolgan vaqt: 1.06 min
#
# Batch 318/391 qayta ishlanmoqda, 64 ta rasm
# Batch 318 tugadi. Vaqt: 0.57s
# O'tgan vaqt: 7.38 min. Taxminiy qolgan vaqt: 0.69 min
#
# Batch 319/391 qayta ishlanmoqda, 64 ta rasm
# Batch 319 tugadi. Vaqt: 0.58s
# O'tgan vaqt: 7.40 min. Taxminiy qolgan vaqt: 0.69 min
#
# Batch 320/391 qayta ishlanmoqda, 64 ta rasm
# Batch 320 tugadi. Vaqt: 0.96s
# O'tgan vaqt: 7.42 min. Taxminiy qolgan vaqt: 1.14 min
# Xususiyatlar va yorliqlar saqlandi: features_batch_31.npy, labels_batch_31.npy
#
# Batch 321/391 qayta ishlanmoqda, 64 ta rasm
# Batch 321 tugadi. Vaqt: 0.69s
# O'tgan vaqt: 7.44 min. Taxminiy qolgan vaqt: 0.81 min
#
# Batch 322/391 qayta ishlanmoqda, 64 ta rasm
# Batch 322 tugadi. Vaqt: 0.86s
# O'tgan vaqt: 7.46 min. Taxminiy qolgan vaqt: 0.99 min
#
# Batch 323/391 qayta ishlanmoqda, 64 ta rasm
# Batch 323 tugadi. Vaqt: 0.57s
# O'tgan vaqt: 7.48 min. Taxminiy qolgan vaqt: 0.65 min
#
# Batch 324/391 qayta ishlanmoqda, 64 ta rasm
# Batch 324 tugadi. Vaqt: 0.86s
# O'tgan vaqt: 7.50 min. Taxminiy qolgan vaqt: 0.96 min
#
# Batch 325/391 qayta ishlanmoqda, 64 ta rasm
# Batch 325 tugadi. Vaqt: 0.57s
# O'tgan vaqt: 7.51 min. Taxminiy qolgan vaqt: 0.63 min
#
# Batch 326/391 qayta ishlanmoqda, 64 ta rasm
# Batch 326 tugadi. Vaqt: 0.56s
# O'tgan vaqt: 7.53 min. Taxminiy qolgan vaqt: 0.61 min
#
# Batch 327/391 qayta ishlanmoqda, 64 ta rasm
# Batch 327 tugadi. Vaqt: 0.86s
# O'tgan vaqt: 7.55 min. Taxminiy qolgan vaqt: 0.92 min
#
# Batch 328/391 qayta ishlanmoqda, 64 ta rasm
# Batch 328 tugadi. Vaqt: 0.57s
# O'tgan vaqt: 7.56 min. Taxminiy qolgan vaqt: 0.60 min
#
# Batch 329/391 qayta ishlanmoqda, 64 ta rasm
# Batch 329 tugadi. Vaqt: 0.86s
# O'tgan vaqt: 7.58 min. Taxminiy qolgan vaqt: 0.89 min
#
# Batch 330/391 qayta ishlanmoqda, 64 ta rasm
# Batch 330 tugadi. Vaqt: 0.87s
# O'tgan vaqt: 7.60 min. Taxminiy qolgan vaqt: 0.88 min
# Xususiyatlar va yorliqlar saqlandi: features_batch_32.npy, labels_batch_32.npy
#
# Batch 331/391 qayta ishlanmoqda, 64 ta rasm
# Batch 331 tugadi. Vaqt: 0.62s
# O'tgan vaqt: 7.62 min. Taxminiy qolgan vaqt: 0.62 min
#
# Batch 332/391 qayta ishlanmoqda, 64 ta rasm
# Batch 332 tugadi. Vaqt: 0.95s
# O'tgan vaqt: 7.64 min. Taxminiy qolgan vaqt: 0.94 min
#
# Batch 333/391 qayta ishlanmoqda, 64 ta rasm
# Batch 333 tugadi. Vaqt: 0.95s
# O'tgan vaqt: 7.67 min. Taxminiy qolgan vaqt: 0.91 min
#
# Batch 334/391 qayta ishlanmoqda, 64 ta rasm
# Batch 334 tugadi. Vaqt: 0.88s
# O'tgan vaqt: 7.69 min. Taxminiy qolgan vaqt: 0.83 min
#
# Batch 335/391 qayta ishlanmoqda, 64 ta rasm
# Batch 335 tugadi. Vaqt: 0.87s
# O'tgan vaqt: 7.71 min. Taxminiy qolgan vaqt: 0.82 min
#
# Batch 336/391 qayta ishlanmoqda, 64 ta rasm
# Batch 336 tugadi. Vaqt: 0.87s
# O'tgan vaqt: 7.73 min. Taxminiy qolgan vaqt: 0.80 min
#
# Batch 337/391 qayta ishlanmoqda, 64 ta rasm
# Batch 337 tugadi. Vaqt: 0.58s
# O'tgan vaqt: 7.75 min. Taxminiy qolgan vaqt: 0.52 min
#
# Batch 338/391 qayta ishlanmoqda, 64 ta rasm
# Batch 338 tugadi. Vaqt: 0.85s
# O'tgan vaqt: 7.77 min. Taxminiy qolgan vaqt: 0.75 min
#
# Batch 339/391 qayta ishlanmoqda, 64 ta rasm
# Batch 339 tugadi. Vaqt: 0.58s
# O'tgan vaqt: 7.78 min. Taxminiy qolgan vaqt: 0.50 min
#
# Batch 340/391 qayta ishlanmoqda, 64 ta rasm
# Batch 340 tugadi. Vaqt: 0.88s
# O'tgan vaqt: 7.80 min. Taxminiy qolgan vaqt: 0.75 min
# Xususiyatlar va yorliqlar saqlandi: features_batch_33.npy, labels_batch_33.npy
#
# Batch 341/391 qayta ishlanmoqda, 64 ta rasm
# Batch 341 tugadi. Vaqt: 0.88s
# O'tgan vaqt: 7.83 min. Taxminiy qolgan vaqt: 0.73 min
#
# Batch 342/391 qayta ishlanmoqda, 64 ta rasm
# Batch 342 tugadi. Vaqt: 0.96s
# O'tgan vaqt: 7.85 min. Taxminiy qolgan vaqt: 0.78 min
#
# Batch 343/391 qayta ishlanmoqda, 64 ta rasm
# Batch 343 tugadi. Vaqt: 0.70s
# O'tgan vaqt: 7.87 min. Taxminiy qolgan vaqt: 0.56 min
#
# Batch 344/391 qayta ishlanmoqda, 64 ta rasm
# Batch 344 tugadi. Vaqt: 0.58s
# O'tgan vaqt: 7.89 min. Taxminiy qolgan vaqt: 0.46 min
#
# Batch 345/391 qayta ishlanmoqda, 64 ta rasm
# Batch 345 tugadi. Vaqt: 0.88s
# O'tgan vaqt: 7.91 min. Taxminiy qolgan vaqt: 0.68 min
#
# Batch 346/391 qayta ishlanmoqda, 64 ta rasm
# Batch 346 tugadi. Vaqt: 0.58s
# O'tgan vaqt: 7.92 min. Taxminiy qolgan vaqt: 0.44 min
#
# Batch 347/391 qayta ishlanmoqda, 64 ta rasm
# Batch 347 tugadi. Vaqt: 0.57s
# O'tgan vaqt: 7.94 min. Taxminiy qolgan vaqt: 0.42 min
#
# Batch 348/391 qayta ishlanmoqda, 64 ta rasm
# Batch 348 tugadi. Vaqt: 0.88s
# O'tgan vaqt: 7.96 min. Taxminiy qolgan vaqt: 0.63 min
#
# Batch 349/391 qayta ishlanmoqda, 64 ta rasm
# Batch 349 tugadi. Vaqt: 0.86s
# O'tgan vaqt: 7.98 min. Taxminiy qolgan vaqt: 0.60 min
#
# Batch 350/391 qayta ishlanmoqda, 64 ta rasm
# Batch 350 tugadi. Vaqt: 0.87s
# O'tgan vaqt: 8.00 min. Taxminiy qolgan vaqt: 0.60 min
# Xususiyatlar va yorliqlar saqlandi: features_batch_34.npy, labels_batch_34.npy
#
# Batch 351/391 qayta ishlanmoqda, 64 ta rasm
# Batch 351 tugadi. Vaqt: 0.87s
# O'tgan vaqt: 8.02 min. Taxminiy qolgan vaqt: 0.58 min
#
# Batch 352/391 qayta ishlanmoqda, 64 ta rasm
# Batch 352 tugadi. Vaqt: 0.87s
# O'tgan vaqt: 8.04 min. Taxminiy qolgan vaqt: 0.56 min
#
# Batch 353/391 qayta ishlanmoqda, 64 ta rasm
# Batch 353 tugadi. Vaqt: 0.96s
# O'tgan vaqt: 8.07 min. Taxminiy qolgan vaqt: 0.61 min
#
# Batch 354/391 qayta ishlanmoqda, 64 ta rasm
# Batch 354 tugadi. Vaqt: 0.63s
# O'tgan vaqt: 8.09 min. Taxminiy qolgan vaqt: 0.39 min
#
# Batch 355/391 qayta ishlanmoqda, 64 ta rasm
# Batch 355 tugadi. Vaqt: 0.87s
# O'tgan vaqt: 8.11 min. Taxminiy qolgan vaqt: 0.52 min
#
# Batch 356/391 qayta ishlanmoqda, 64 ta rasm
# Batch 356 tugadi. Vaqt: 0.58s
# O'tgan vaqt: 8.12 min. Taxminiy qolgan vaqt: 0.34 min
#
# Batch 357/391 qayta ishlanmoqda, 64 ta rasm
# Batch 357 tugadi. Vaqt: 0.59s
# O'tgan vaqt: 8.14 min. Taxminiy qolgan vaqt: 0.33 min
#
# Batch 358/391 qayta ishlanmoqda, 64 ta rasm
# Batch 358 tugadi. Vaqt: 0.57s
# O'tgan vaqt: 8.16 min. Taxminiy qolgan vaqt: 0.32 min
#
# Batch 359/391 qayta ishlanmoqda, 64 ta rasm
# Batch 359 tugadi. Vaqt: 0.57s
# O'tgan vaqt: 8.17 min. Taxminiy qolgan vaqt: 0.30 min
#
# Batch 360/391 qayta ishlanmoqda, 64 ta rasm
# Batch 360 tugadi. Vaqt: 0.59s
# O'tgan vaqt: 8.19 min. Taxminiy qolgan vaqt: 0.31 min
# Xususiyatlar va yorliqlar saqlandi: features_batch_35.npy, labels_batch_35.npy
#
# Batch 361/391 qayta ishlanmoqda, 64 ta rasm
# Batch 361 tugadi. Vaqt: 0.58s
# O'tgan vaqt: 8.20 min. Taxminiy qolgan vaqt: 0.29 min
#
# Batch 362/391 qayta ishlanmoqda, 64 ta rasm
# Batch 362 tugadi. Vaqt: 0.88s
# O'tgan vaqt: 8.22 min. Taxminiy qolgan vaqt: 0.42 min
#
# Batch 363/391 qayta ishlanmoqda, 64 ta rasm
# Batch 363 tugadi. Vaqt: 0.88s
# O'tgan vaqt: 8.25 min. Taxminiy qolgan vaqt: 0.41 min
#
# Batch 364/391 qayta ishlanmoqda, 64 ta rasm
# Batch 364 tugadi. Vaqt: 0.96s
# O'tgan vaqt: 8.27 min. Taxminiy qolgan vaqt: 0.43 min
#
# Batch 365/391 qayta ishlanmoqda, 64 ta rasm
# Batch 365 tugadi. Vaqt: 0.99s
# O'tgan vaqt: 8.30 min. Taxminiy qolgan vaqt: 0.43 min
#
# Batch 366/391 qayta ishlanmoqda, 64 ta rasm
# Batch 366 tugadi. Vaqt: 0.87s
# O'tgan vaqt: 8.32 min. Taxminiy qolgan vaqt: 0.36 min
#
# Batch 367/391 qayta ishlanmoqda, 64 ta rasm
# Batch 367 tugadi. Vaqt: 0.87s
# O'tgan vaqt: 8.34 min. Taxminiy qolgan vaqt: 0.35 min
#
# Batch 368/391 qayta ishlanmoqda, 64 ta rasm
# Batch 368 tugadi. Vaqt: 0.58s
# O'tgan vaqt: 8.35 min. Taxminiy qolgan vaqt: 0.22 min
#
# Batch 369/391 qayta ishlanmoqda, 64 ta rasm
# Batch 369 tugadi. Vaqt: 0.57s
# O'tgan vaqt: 8.37 min. Taxminiy qolgan vaqt: 0.21 min
#
# Batch 370/391 qayta ishlanmoqda, 64 ta rasm
# Batch 370 tugadi. Vaqt: 0.57s
# O'tgan vaqt: 8.38 min. Taxminiy qolgan vaqt: 0.20 min
# Xususiyatlar va yorliqlar saqlandi: features_batch_36.npy, labels_batch_36.npy
#
# Batch 371/391 qayta ishlanmoqda, 64 ta rasm
# Batch 371 tugadi. Vaqt: 0.86s
# O'tgan vaqt: 8.40 min. Taxminiy qolgan vaqt: 0.29 min
#
# Batch 372/391 qayta ishlanmoqda, 64 ta rasm
# Batch 372 tugadi. Vaqt: 0.58s
# O'tgan vaqt: 8.42 min. Taxminiy qolgan vaqt: 0.19 min
#
# Batch 373/391 qayta ishlanmoqda, 64 ta rasm
# Batch 373 tugadi. Vaqt: 0.87s
# O'tgan vaqt: 8.44 min. Taxminiy qolgan vaqt: 0.26 min
#
# Batch 374/391 qayta ishlanmoqda, 64 ta rasm
# Batch 374 tugadi. Vaqt: 0.90s
# O'tgan vaqt: 8.46 min. Taxminiy qolgan vaqt: 0.25 min
#
# Batch 375/391 qayta ishlanmoqda, 64 ta rasm
# Batch 375 tugadi. Vaqt: 0.68s
# O'tgan vaqt: 8.48 min. Taxminiy qolgan vaqt: 0.18 min
#
# Batch 376/391 qayta ishlanmoqda, 64 ta rasm
# Batch 376 tugadi. Vaqt: 0.98s
# O'tgan vaqt: 8.50 min. Taxminiy qolgan vaqt: 0.25 min
#
# Batch 377/391 qayta ishlanmoqda, 64 ta rasm
# Batch 377 tugadi. Vaqt: 0.59s
# O'tgan vaqt: 8.52 min. Taxminiy qolgan vaqt: 0.14 min
#
# Batch 378/391 qayta ishlanmoqda, 64 ta rasm
# Batch 378 tugadi. Vaqt: 0.57s
# O'tgan vaqt: 8.54 min. Taxminiy qolgan vaqt: 0.12 min
#
# Batch 379/391 qayta ishlanmoqda, 64 ta rasm
# Batch 379 tugadi. Vaqt: 0.57s
# O'tgan vaqt: 8.55 min. Taxminiy qolgan vaqt: 0.11 min
#
# Batch 380/391 qayta ishlanmoqda, 64 ta rasm
# Batch 380 tugadi. Vaqt: 0.85s
# O'tgan vaqt: 8.57 min. Taxminiy qolgan vaqt: 0.16 min
# Xususiyatlar va yorliqlar saqlandi: features_batch_37.npy, labels_batch_37.npy
#
# Batch 381/391 qayta ishlanmoqda, 64 ta rasm
# Batch 381 tugadi. Vaqt: 0.88s
# O'tgan vaqt: 8.59 min. Taxminiy qolgan vaqt: 0.15 min
#
# Batch 382/391 qayta ishlanmoqda, 64 ta rasm
# Batch 382 tugadi. Vaqt: 0.59s
# O'tgan vaqt: 8.61 min. Taxminiy qolgan vaqt: 0.09 min
#
# Batch 383/391 qayta ishlanmoqda, 64 ta rasm
# Batch 383 tugadi. Vaqt: 0.58s
# O'tgan vaqt: 8.62 min. Taxminiy qolgan vaqt: 0.08 min
#
# Batch 384/391 qayta ishlanmoqda, 64 ta rasm
# Batch 384 tugadi. Vaqt: 0.58s
# O'tgan vaqt: 8.64 min. Taxminiy qolgan vaqt: 0.07 min
#
# Batch 385/391 qayta ishlanmoqda, 64 ta rasm
# Batch 385 tugadi. Vaqt: 0.86s
# O'tgan vaqt: 8.66 min. Taxminiy qolgan vaqt: 0.09 min
#
# Batch 386/391 qayta ishlanmoqda, 64 ta rasm
# Batch 386 tugadi. Vaqt: 0.88s
# O'tgan vaqt: 8.68 min. Taxminiy qolgan vaqt: 0.07 min
#
# Batch 387/391 qayta ishlanmoqda, 64 ta rasm
# Batch 387 tugadi. Vaqt: 0.96s
# O'tgan vaqt: 8.70 min. Taxminiy qolgan vaqt: 0.06 min
#
# Batch 388/391 qayta ishlanmoqda, 64 ta rasm
# Batch 388 tugadi. Vaqt: 0.86s
# O'tgan vaqt: 8.73 min. Taxminiy qolgan vaqt: 0.04 min
#
# Batch 389/391 qayta ishlanmoqda, 64 ta rasm
# Batch 389 tugadi. Vaqt: 0.88s
# O'tgan vaqt: 8.75 min. Taxminiy qolgan vaqt: 0.03 min
#
# Batch 390/391 qayta ishlanmoqda, 64 ta rasm
# Batch 390 tugadi. Vaqt: 0.87s
# O'tgan vaqt: 8.77 min. Taxminiy qolgan vaqt: 0.01 min
# Xususiyatlar va yorliqlar saqlandi: features_batch_38.npy, labels_batch_38.npy
#
# Batch 391/391 qayta ishlanmoqda, 40 ta rasm
# Batch 391 tugadi. Vaqt: 20.65s
# O'tgan vaqt: 9.12 min. Taxminiy qolgan vaqt: 0.00 min
# Xususiyatlar va yorliqlar saqlandi: features_batch_39.npy, labels_batch_39.npy

# %%
print(f"\nBarcha xususiyatlar ajratildi va saqlandi! Vaqt: {(time.time() - start_time)/60:.2f} min")

# Saqlangan fayllardan ma'lumotlarni o'qib, model yaratish
print("\nSaqlangan xususiyatlardan train/test ma'lumotlarini tayyorlash...")

# Hamma xususiyatlar va yorliqlarni to'plash
all_features = []
all_labels = []

for feat_file, label_file in zip(feature_files, label_files):
    features = np.load(feat_file)
    labels = np.load(label_file)

    # Train/test ga ajratish uchun saqlash
    all_features.append(features)
    all_labels.append(labels)

    # Xotiradan tozalash
    features = None
    labels = None
    gc.collect()
# Out:
# Barcha xususiyatlar ajratildi va saqlandi! Vaqt: 9.13 min
#
# Saqlangan xususiyatlardan train/test ma'lumotlarini tayyorlash...

# %%
# Train/test ga ajratish uchun ma'lumotlarni birlashtirish
X = np.vstack(all_features)
y = np.concatenate(all_labels)

print(f"Jami xususiyatlar: {X.shape}, Jami yorliqlar: {y.shape}")

# Xotiradan tozalash
all_features = None
all_labels = None
gc.collect()

# Ma'lumotlarni train/test ga ajratish
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=7)

# Xotiradan tozalash
X = None
gc.collect()
# Out:
# Jami xususiyatlar: (2536, 25088), Jami yorliqlar: (2536,)
# 0

# %% [markdown]
# ## **4. Train a LR Classifier using those features**
#
# First let's store our extracted feature info in a format that can loaded directly by sklearn.

# %%
# Logistic Regression modelini o'rgatish
print("Logistic Regression modelini o'rgatish...")
glm = LogisticRegression(C=0.1, max_iter=1000)
glm.fit(X_train, y_train)
# Out:
# Logistic Regression modelini o'rgatish...
# LogisticRegression(C=0.1, max_iter=1000)

# %% [markdown]
# ## **5. Test some inferences**

# %%
# Test natijalarini baholash
accuracy = glm.score(X_test, y_test)
print(f'Logistic Regression modeli aniqligi: {accuracy*100:.2f}%')

# Test natijalarini tekshirish
print("Test rasmlarida sinovdan o'tkazish...")
image_names_test = os.listdir("./test1")
image_paths_test = ["./test1/" + x for x in image_names_test]
# Out:
# Logistic Regression modeli aniqligi: 98.62%
# Test rasmlarida sinovdan o'tkazish...

# %%
# Kamroq test rasmlarini tanlash (xotirani tejash uchun)
test_sample = random.sample(image_paths_test, min(12, len(image_paths_test)))

# Test rasmlarini bashorat qilish
predictions = []

for test_path in test_sample:
    try:
        # Rasmni yuklash va qayta ishlash
        image = load_img(test_path, target_size=(224, 224))
        image = img_to_array(image)
        image = np.expand_dims(image, axis=0)
        image = preprocess_input(image)

        # Xususiyatlarni olish
        features = model.predict(image, verbose=0)
        features = features.reshape(1, -1)

        # Bashorat qilish
        result = glm.predict(features)[0]
        label = 'dog' if result == 1 else 'cat'
        predictions.append(label)

        # Xotiradan tozalash
        features = None
        image = None
        gc.collect()
    except Exception as e:
        print(f"Test rasmi xatosi: {test_path}: {str(e)}")
        predictions.append("error")

# %%
# Bashoratlarni ko'rsatish
for i, (path, pred) in enumerate(zip(test_sample, predictions)):
    print(f"{i+1}. {path} - Bashorat: {pred}")

# Vaqtinchalik fayllarni tozalash (ixtiyoriy)
for file in feature_files + label_files:
    if os.path.exists(file):
        os.remove(file)

print("\nIsh yakunlandi!")
# Out:
# 1. ./test1/10652.jpg - Bashorat: cat
# 2. ./test1/11894.jpg - Bashorat: dog
# 3. ./test1/238.jpg - Bashorat: dog
# 4. ./test1/10844.jpg - Bashorat: dog
# 5. ./test1/8890.jpg - Bashorat: cat
# 6. ./test1/7353.jpg - Bashorat: dog
# 7. ./test1/9444.jpg - Bashorat: cat
# 8. ./test1/9938.jpg - Bashorat: dog
# 9. ./test1/558.jpg - Bashorat: dog
# 10. ./test1/565.jpg - Bashorat: dog
# 11. ./test1/4691.jpg - Bashorat: dog
# 12. ./test1/9284.jpg - Bashorat: dog
#
# Ish yakunlandi!

# %% [markdown]
# ## **How do we compare to Kaggle's top 10?**
# https://www.kaggle.com/c/dogs-vs-cats/leaderboard
#
# We just got 98.34%, second place! Not too shabby :)
#
# ![](https://github.com/rajeevratan84/ModernComputerVision/raw/main/Screenshot%202021-05-17%20at%208.09.25%20pm.png)
